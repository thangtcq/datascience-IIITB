# %% [markdown]
# # Liquor Sales Data Analysis

# %% [markdown]
# ## Objective
#
# In this case study, you will learn the principles of hands-on data processing and analysis using
# a detailed dataset on liquor sales spanning 2020 to 2025. This assignment aims to give you
# practical experience in processing large datasets using tech stacks such as AWS RDS, HBase,
# and Hadoop MapReduce. You will not only apply the techniques covered in the project modules,
# but also gain insights into the complexities of business data analytics. At the end of this
# assignment, you will have developed a robust understanding of the following:
# • Data ingestion processes using cloud-based tools like AWS RDS and HBase.
# • Data cleaning and preparation to ensure high-quality analysis.
# • Applying MapReduce to solve real-world analytics problems.
# • Creating actionable insights and recommendations based on the analysis.
# This hands-on approach will bridge the gap between theoretical learning and practical implementation,
# preparing you for real-world challenges in the field of data analytics.

# %% [markdown]
# # Business Objective:
# The liquor industry is a significant contributor to the retail economy, particularly in regions where
# sales are highly regulated and tracked. For liquor businesses, understanding sales trends is vital to
# maintaining competitive advantage, meeting customer demand, and ensuring efficient operations.
# As an analyst, you are tasked with analyzing detailed liquor sales data from 2020 to 2025 to uncover
# patterns and insights that can drive strategic decision-making. The objective is to identify trends in
# consumer preferences, regional sales performance, and product popularity, enabling stakeholders to
# optimize inventory management, boost profitability, and enhance customer satisfaction.

# %% [markdown]
# ## Hadoop and MapReduce Assignment Tasks:
#
# <br> Data Cleaning Tasks: </br>
# <br>Task 1:  Data Cleaning</br>
#
# <br> Data Ingestion Tasks: </br>
# <br>Task 2: Upload Liquor Sales Data to AWS RDS</br>
# <br>Task 3: Ingest Data into HBase</br>
#
#
# <r>Data Analysis Using MapReduce:</br>
# <br>Task 4: Total Revenue by Store</br>
# <br>Task 5: Top-Selling Liquor Categories</br>
# <br>Task 6: County-Level Sales Analysis</br>
# <br>Task 7: Store Performance Analysis</br>
# <br>Task 8: Trends in Liquor Sales Over Time</br>
# <br>Task 9: Vendor Performance</br>
#
#
# **NOTE:** The marks given along with headings and sub-headings are cumulative marks for those particular headings/sub-headings.<br>
#
# The actual marks for each task are specified within the tasks themselves.
#
# For example, marks given with heading *2* or sub-heading *2.1* are the cumulative marks, for your reference only. <br>
#
# The marks you will receive for completing tasks are given with the tasks.
#
# Suppose the marks for two tasks are: 3 marks for 2.1.1 and 2 marks for 3.2.2, or
# * 2.1.1 [3 marks]
# * 3.2.2 [2 marks]
#
# then, you will earn 3 marks for completing task 2.1.1 and 2 marks for completing task 3.2.2.

# %% [markdown]
# ---

# %% [markdown]
# ## Data Understanding
# The dataset link can be accessed from the following [link](https://liquor-data.s3.us-east-1.amazonaws.com/Liquor_Sales.csv).
# The dataset contains liquor sales data from multiple stores across various states, providing rich information for analysis. The fields are as follows:

# %% [markdown]
# | Variable              | Class            | Description                                                     |
# |-----------------------|------------------|-----------------------------------------------------------------|
# | Invoice/Item Number   | String/Integer   | Unique identifier for each sale.                                |
# | Date                  | Date             | The date of the sale.                                           |
# | Store Number          | Integer          | Unique identifier for the store.                                |
# | Store Name            | String           | Name of the store.                                              |
# | Address               | String           | Store address.                                                  |
# | City                  | String           | City where the store is located.                                |
# | Zip Code              | String/Integer   | ZIP code of the store location.                                 |
# | Store Location        | String/GeoPoint  | GPS coordinates of the store.                                   |
# | County Number         | Integer          | Unique identifier for the county.                               |
# | County                | String           | Name of the county.                                             |
# | Category              | Integer          | Liquor category code.                                           |
# | Category Name         | String           | Name of the liquor category (e.g., Whiskey, Vodka).             |
# | Vendor Number         | Integer          | Vendor's unique identifier.                                     |
# | Vendor Name           | String           | Name of the vendor/distributor.                                 |
# | Item Number           | Integer          | Product's unique identifier.                                    |
# | Item Description      | String           | Description of the liquor product.                              |
# | Pack                  | Integer          | Number of bottles in a pack.                                    |
# | Bottle Volume (ml)    | Float/Integer    | Volume of a single bottle in milliliters.                       |
# | State Bottle Cost     | Float            | Cost per bottle for the state.                                  |
# | State Bottle Retail   | Float            | Retail price per bottle.                                        |
# | Bottles Sold          | Integer          | Number of bottles sold.                                         |
# | Sale (Dollars)        | Float            | Total revenue from the sale.                                    |
# | Volume Sold (Liters)  | Float            | Volume sold in liters.                                          |
# | Volume Sold (Gallons) | Float            | Volume sold in gallons.                                         |

# %% [markdown]
# ### Import Libraries and Load Dataset

# %%
# Import the libraries you will be using for analysis
import pandas as pd
import numpy as np
from mrjob.job import MRJob
import csv

# %% [markdown]
# ## **1** Data Cleaning
# <font color = red>[5 marks]</font> <br>

# %% [markdown]
# #### **1.1** Fixing Columns

# %% [markdown]
# #### **1.2** Fixing Rows

# %%
import pandas as pd

df = pd.read_csv('Liquor_Sales.csv', low_memory=False)
df.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0        S24127700024  02/19/2015          3678
# 1        S15066200002  10/10/2013          2633
# 2        S19323500030  06/03/2014          2607
# 3        S23334500013  01/06/2015          4810
# 4        S09742200010  12/27/2012          4025
#
#                              Store Name                   Address  \
# 0                       Smoke Shop, The           1918 SE 14TH ST
# 1          Hy-Vee #3 / BDI / Des Moines           3221 SE 14TH ST
# 2  Hy-Vee Wine and Spirits / Shenandoah            520 SO FREMONT
# 3                Kum & Go #518 / Ankeny  3603 NE OTTERVIEW CIRCLE
# 4               Karam Kaur Khasriya Llc               702 13TH ST
#
#            City Zip Code                Store Location  County Number  County  \
# 0    DES MOINES    50320  POINT (-93.597011 41.570844)           77.0    Polk
# 1    DES MOINES    50320  POINT (-93.596754 41.554101)           77.0    Polk
# 2    SHENANDOAH    51601  POINT (-95.385111 40.761736)           73.0    Page
# 3        ANKENY    50021  POINT (-93.572458 41.760989)           77.0    Polk
# 4  BELLE PLAINE    52208  POINT (-92.277759 41.897052)            6.0  Benton
#
#    ...  Item Number                 Item Description  Pack Bottle Volume (ml)  \
# 0  ...        41783     Uv Blue Raspberry Vodka Mini     6                500
# 1  ...       904969  Sabe Premiom Sake Double Barrel     6                750
# 2  ...        45277              Paramount White Rum    12               1000
# 3  ...        43121        Bacardi Superior Rum Mini    12                500
# 4  ...        11298      Crown Royal Canadian Whisky     6               1750
#
#   State Bottle Cost State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 0              4.89                7.34             2           14.68
# 1             14.99               22.49             6          134.94
# 2              4.34                6.51            12           78.12
# 3              5.54                8.31             1            8.31
# 4             31.00               46.49             2           92.98
#
#    Volume Sold (Liters)  Volume Sold (Gallons)
# 0                   1.0                   0.26
# 1                   4.5                   1.19
# 2                  12.0                   3.17
# 3                   0.5                   0.13
# 4                   3.5                   0.92
#
# [5 rows x 24 columns]

# %% [markdown]
# #### **1.3** Handling Missing Values

# %%
df.isnull().sum()
df.dropna(inplace=True)  # Xoá dòng thiếu
df = df[['Invoice/Item Number', 'City', 'Vendor Name', 'Item Description', 'Bottles Sold', 'Sale (Dollars)']]
df.dropna(inplace=True)
df.columns = ['invoice_item', 'city', 'vendor', 'item', 'bottles', 'dollars']
df['bottles'] = df['bottles'].astype(int)
df['dollars'] = df['dollars'].astype(float)

# %% [markdown]
# #### **1.4** Handling Outliers

# %%
df.to_csv('Liquor_Sales_Cleaned.csv', index=False)

# %% [markdown]
# ## **2** Data Ingestion Tasks
# <font color = red>[15 marks]</font> <br>

# %% [markdown]
# #### 2.1 Upload Liquor Sales Data to AWS RDS
# <font color = red>[5 marks]</font> <br>

# %%
import mysql.connector

# RDS connection configuration
config = {
    'host': 'demodb.cc0it5atzdlu.us-east-1.rds.amazonaws.com',
    'user': 'admin',
    'password': 'upGrad.123',
    'database': 'liquor_sales'
}

try:
    conn = mysql.connector.connect(**config)
    cursor = conn.cursor()
    
    # Run a test SELECT query to verify connection
    cursor.execute("""
        SELECT invoice_number, city, vendor_name, item_description, bottles_sold, sale_dollars
        FROM sales_data
        LIMIT 5;
    """)

    rows = cursor.fetchall()
    print("Connection successful! Displaying first 5 rows:")
    for row in rows:
        print(row)

    cursor.close()
    conn.close()

except mysql.connector.Error as err:
    print(f"Failed to connect to RDS: {err}")
# Out:
# Connection successful! Displaying first 5 rows:
# ('S24127700024', 'DES MOINES', 'Phillips Beverage Company', 'Uv Blue Raspberry Vodka Mini', 2, Decimal('14.68'))
# ('S15066200002', 'DES MOINES', 'MHW Ltd', 'Sabe Premiom Sake Double Barrel', 6, Decimal('134.94'))
# ('S19323500030', 'SHENANDOAH', 'Luxco-St Louis', 'Paramount White Rum', 12, Decimal('78.12'))
# ('S23334500013', 'ANKENY', 'Bacardi U.S.A., Inc.', 'Bacardi Superior Rum Mini', 1, Decimal('8.31'))
# ('S09742200010', 'BELLE PLAINE', 'Diageo Americas', 'Crown Royal Canadian Whisky', 2, Decimal('92.98'))

# %% [markdown]
# #### 2.2 Ingest Data to HBase
# <font color = red>[10 marks]</font> <br>

# %%
import happybase
import csv
import time

# Connect to HBase Thrift server
connection = happybase.Connection(
    host='ec2-34-200-220-200.compute-1.amazonaws.com',
    port=9090
)
connection.open()

# Create HBase table if it doesn't exist
table_name = 'liquor_sales_hbase'
if table_name.encode() not in connection.tables():
    connection.create_table(
        table_name,
        {'info': dict()}  # Column family 'info'
    )

table = connection.table(table_name)

start_time = time.time()
batch_size = 1000
batch = table.batch()

with open('Liquor_Sales_Cleaned.csv', 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for i, row in enumerate(reader, 1):  # start at 1 for easier mod calculation
        row_key = row['invoice_item']
        data = {
            b'info:city': row['city'].encode(),
            b'info:vendor': row['vendor'].encode(),
            b'info:item': row['item'].encode(),
            b'info:bottles': str(row['bottles']).encode(),
            b'info:dollars': str(row['dollars']).encode()
        }
        batch.put(row_key, data)

        if i % batch_size == 0:
            batch.send()
            print(f"Ingested {i} rows...")

# send remaining data
batch.send()
print(f"Finished ingesting. Total rows: {i}")
print(f"Total time: {round(time.time() - start_time, 2)} seconds")

connection.close()
# Out:
# Ingested 1000 rows...
# Ingested 2000 rows...
# Ingested 3000 rows...
# Ingested 4000 rows...
# Ingested 5000 rows...
# Ingested 6000 rows...
# Ingested 7000 rows...
# Ingested 8000 rows...
# Ingested 9000 rows...
# Ingested 10000 rows...
# Ingested 11000 rows...
# Ingested 12000 rows...
# Ingested 13000 rows...
# Ingested 14000 rows...
# Ingested 15000 rows...
# Ingested 16000 rows...
# Ingested 17000 rows...
# Ingested 18000 rows...
# Ingested 19000 rows...
# Ingested 20000 rows...
# Ingested 21000 rows...
# Ingested 22000 rows...
# Ingested 23000 rows...
# Ingested 24000 rows...
# Ingested 25000 rows...
# Ingested 26000 rows...
# Ingested 27000 rows...
# Ingested 28000 rows...
# Ingested 29000 rows...
# Ingested 30000 rows...
# Ingested 31000 rows...
# Ingested 32000 rows...
# Ingested 33000 rows...
# Ingested 34000 rows...
# Ingested 35000 rows...
# Ingested 36000 rows...
# Ingested 37000 rows...
# Ingested 38000 rows...
# Ingested 39000 rows...
# Ingested 40000 rows...
# Ingested 41000 rows...
# Ingested 42000 rows...
# Ingested 43000 rows...
# Ingested 44000 rows...
# Ingested 45000 rows...
# Ingested 46000 rows...
# Ingested 47000 rows...
# Ingested 48000 rows...
# Ingested 49000 rows...
# Ingested 50000 rows...
# Ingested 51000 rows...
# Ingested 52000 rows...
# Ingested 53000 rows...
# Ingested 54000 rows...
# Ingested 55000 rows...
# Ingested 56000 rows...
# Ingested 57000 rows...
# Ingested 58000 rows...
# Ingested 59000 rows...
# Ingested 60000 rows...
# Ingested 61000 rows...
# Ingested 62000 rows...
# Ingested 63000 rows...
# Ingested 64000 rows...
# Ingested 65000 rows...
# Ingested 66000 rows...
# Ingested 67000 rows...
# Ingested 68000 rows...
# Ingested 69000 rows...
# Ingested 70000 rows...
# Ingested 71000 rows...
# Ingested 72000 rows...
# Ingested 73000 rows...
# Ingested 74000 rows...
# Ingested 75000 rows...
# Ingested 76000 rows...
# Ingested 77000 rows...
# Ingested 78000 rows...
# Ingested 79000 rows...
# Ingested 80000 rows...
# Ingested 81000 rows...
# Ingested 82000 rows...
# Ingested 83000 rows...
# Ingested 84000 rows...
# Ingested 85000 rows...
# Ingested 86000 rows...
# Ingested 87000 rows...
# Ingested 88000 rows...
# Ingested 89000 rows...
# Ingested 90000 rows...
# Ingested 91000 rows...
# Ingested 92000 rows...
# Ingested 93000 rows...
# Ingested 94000 rows...
# Ingested 95000 rows...
# Ingested 96000 rows...
# Ingested 97000 rows...
# Ingested 98000 rows...
# Ingested 99000 rows...
# Ingested 100000 rows...
# Ingested 101000 rows...
# Ingested 102000 rows...
# Ingested 103000 rows...
# Ingested 104000 rows...
# Ingested 105000 rows...
# Ingested 106000 rows...
# Ingested 107000 rows...
# Ingested 108000 rows...
# Ingested 109000 rows...
# Ingested 110000 rows...
# Ingested 111000 rows...
# Ingested 112000 rows...
# Ingested 113000 rows...
# Ingested 114000 rows...
# Ingested 115000 rows...
# Ingested 116000 rows...
# Ingested 117000 rows...
# Ingested 118000 rows...
# Ingested 119000 rows...
# Ingested 120000 rows...
# Ingested 121000 rows...
# Ingested 122000 rows...
# Ingested 123000 rows...
# Ingested 124000 rows...
# Ingested 125000 rows...
# Ingested 126000 rows...
# Ingested 127000 rows...
# Ingested 128000 rows...
# Ingested 129000 rows...
# Ingested 130000 rows...
# Ingested 131000 rows...
# Ingested 132000 rows...
# Ingested 133000 rows...
# Ingested 134000 rows...
# Ingested 135000 rows...
# Ingested 136000 rows...
# Ingested 137000 rows...
# Ingested 138000 rows...
# Ingested 139000 rows...
# Ingested 140000 rows...
# Ingested 141000 rows...
# Ingested 142000 rows...
# Ingested 143000 rows...
# Ingested 144000 rows...
# Ingested 145000 rows...
# Ingested 146000 rows...
# Ingested 147000 rows...
# Ingested 148000 rows...
# Ingested 149000 rows...
# Ingested 150000 rows...
# Ingested 151000 rows...
# Ingested 152000 rows...
# Ingested 153000 rows...
# Ingested 154000 rows...
# Ingested 155000 rows...
# Ingested 156000 rows...
# Ingested 157000 rows...
# Ingested 158000 rows...
# Ingested 159000 rows...
# Ingested 160000 rows...
# Ingested 161000 rows...
# Ingested 162000 rows...
# Ingested 163000 rows...
# Ingested 164000 rows...
# Ingested 165000 rows...
# Ingested 166000 rows...
# Ingested 167000 rows...
# Ingested 168000 rows...
# Ingested 169000 rows...
# Ingested 170000 rows...
# Ingested 171000 rows...
# Ingested 172000 rows...
# Ingested 173000 rows...
# Ingested 174000 rows...
# Ingested 175000 rows...
# Ingested 176000 rows...
# Ingested 177000 rows...
# Ingested 178000 rows...
# Ingested 179000 rows...
# Ingested 180000 rows...
# Ingested 181000 rows...
# Ingested 182000 rows...
# Ingested 183000 rows...
# Ingested 184000 rows...
# Ingested 185000 rows...
# Ingested 186000 rows...
# Ingested 187000 rows...
# Ingested 188000 rows...
# Ingested 189000 rows...
# Ingested 190000 rows...
# Ingested 191000 rows...
# Ingested 192000 rows...
# Ingested 193000 rows...
# Ingested 194000 rows...
# Ingested 195000 rows...
# Ingested 196000 rows...
# Ingested 197000 rows...
# Ingested 198000 rows...
# Ingested 199000 rows...
# Ingested 200000 rows...
# Ingested 201000 rows...
# Ingested 202000 rows...
# Ingested 203000 rows...
# Ingested 204000 rows...
# Ingested 205000 rows...
# Ingested 206000 rows...
# Ingested 207000 rows...
# Ingested 208000 rows...
# Ingested 209000 rows...
# Ingested 210000 rows...
# Ingested 211000 rows...
# Ingested 212000 rows...
# Ingested 213000 rows...
# Ingested 214000 rows...
# Ingested 215000 rows...
# Ingested 216000 rows...
# Ingested 217000 rows...
# Ingested 218000 rows...
# Ingested 219000 rows...
# Ingested 220000 rows...
# Ingested 221000 rows...
# Ingested 222000 rows...
# Ingested 223000 rows...
# Ingested 224000 rows...
# Ingested 225000 rows...
# Ingested 226000 rows...
# Ingested 227000 rows...
# Ingested 228000 rows...
# Ingested 229000 rows...
# Ingested 230000 rows...
# Ingested 231000 rows...
# Ingested 232000 rows...
# Ingested 233000 rows...
# Ingested 234000 rows...
# Ingested 235000 rows...
# Ingested 236000 rows...
# Ingested 237000 rows...
# Ingested 238000 rows...
# Ingested 239000 rows...
# Ingested 240000 rows...
# Ingested 241000 rows...
# Ingested 242000 rows...
# Ingested 243000 rows...
# Ingested 244000 rows...
# Ingested 245000 rows...
# Ingested 246000 rows...
# Ingested 247000 rows...
# Ingested 248000 rows...
# Ingested 249000 rows...
# Ingested 250000 rows...
# Ingested 251000 rows...
# Ingested 252000 rows...
# Ingested 253000 rows...
# Ingested 254000 rows...
# Ingested 255000 rows...
# Ingested 256000 rows...
# Ingested 257000 rows...
# Ingested 258000 rows...
# Ingested 259000 rows...
# Ingested 260000 rows...
# Ingested 261000 rows...
# Ingested 262000 rows...
# Ingested 263000 rows...
# Ingested 264000 rows...
# Ingested 265000 rows...
# Ingested 266000 rows...
# Ingested 267000 rows...
# Ingested 268000 rows...
# Ingested 269000 rows...
# Ingested 270000 rows...
# Ingested 271000 rows...
# Ingested 272000 rows...
# Ingested 273000 rows...
# Ingested 274000 rows...
# Ingested 275000 rows...
# Ingested 276000 rows...
# Ingested 277000 rows...
# Ingested 278000 rows...
# Ingested 279000 rows...
# Ingested 280000 rows...
# Ingested 281000 rows...
# Ingested 282000 rows...
# Ingested 283000 rows...
# Ingested 284000 rows...
# Ingested 285000 rows...
# Ingested 286000 rows...
# Ingested 287000 rows...
# Ingested 288000 rows...
# Ingested 289000 rows...
# Ingested 290000 rows...
# Ingested 291000 rows...
# Ingested 292000 rows...
# Ingested 293000 rows...
# Ingested 294000 rows...
# Ingested 295000 rows...
# Ingested 296000 rows...
# Ingested 297000 rows...
# Ingested 298000 rows...
# Ingested 299000 rows...
# Ingested 300000 rows...
# Ingested 301000 rows...
# Ingested 302000 rows...
# Ingested 303000 rows...
# Ingested 304000 rows...
# Ingested 305000 rows...
# Ingested 306000 rows...
# Ingested 307000 rows...
# Ingested 308000 rows...
# Ingested 309000 rows...
# Ingested 310000 rows...
# Ingested 311000 rows...
# Ingested 312000 rows...
# Ingested 313000 rows...
# Ingested 314000 rows...
# Ingested 315000 rows...
# Ingested 316000 rows...
# Ingested 317000 rows...
# Ingested 318000 rows...
# Ingested 319000 rows...
# Ingested 320000 rows...
# Ingested 321000 rows...
# Ingested 322000 rows...
# Ingested 323000 rows...
# Ingested 324000 rows...
# Ingested 325000 rows...
# Ingested 326000 rows...
# Ingested 327000 rows...
# Ingested 328000 rows...
# Ingested 329000 rows...
# Ingested 330000 rows...
# Ingested 331000 rows...
# Ingested 332000 rows...
# Ingested 333000 rows...
# Ingested 334000 rows...
# Ingested 335000 rows...
# Ingested 336000 rows...
# Ingested 337000 rows...
# Ingested 338000 rows...
# Ingested 339000 rows...
# Ingested 340000 rows...
# Ingested 341000 rows...
# Ingested 342000 rows...
# Ingested 343000 rows...
# Ingested 344000 rows...
# Ingested 345000 rows...
# Ingested 346000 rows...
# Ingested 347000 rows...
# Ingested 348000 rows...
# Ingested 349000 rows...
# Ingested 350000 rows...
# Ingested 351000 rows...
# Ingested 352000 rows...
# Ingested 353000 rows...
# Ingested 354000 rows...
# Ingested 355000 rows...
# Ingested 356000 rows...
# Ingested 357000 rows...
# Ingested 358000 rows...
# Ingested 359000 rows...
# Ingested 360000 rows...
# Ingested 361000 rows...
# Ingested 362000 rows...
# Ingested 363000 rows...
# Ingested 364000 rows...
# Ingested 365000 rows...
# Ingested 366000 rows...
# Ingested 367000 rows...
# Ingested 368000 rows...
# Ingested 369000 rows...
# Ingested 370000 rows...
# Ingested 371000 rows...
# Ingested 372000 rows...
# Ingested 373000 rows...
# Ingested 374000 rows...
# Ingested 375000 rows...
# Ingested 376000 rows...
# Ingested 377000 rows...
# Ingested 378000 rows...
# Ingested 379000 rows...
# Ingested 380000 rows...
# Ingested 381000 rows...
# Ingested 382000 rows...
# Ingested 383000 rows...
# Ingested 384000 rows...
# Ingested 385000 rows...
# Ingested 386000 rows...
# Ingested 387000 rows...
# Ingested 388000 rows...
# Ingested 389000 rows...
# Ingested 390000 rows...
# Ingested 391000 rows...
# Ingested 392000 rows...
# Ingested 393000 rows...
# Ingested 394000 rows...
# Ingested 395000 rows...
# Ingested 396000 rows...
# Ingested 397000 rows...
# Ingested 398000 rows...
# Ingested 399000 rows...
# Ingested 400000 rows...
# Ingested 401000 rows...
# Ingested 402000 rows...
# Ingested 403000 rows...
# Ingested 404000 rows...
# Ingested 405000 rows...
# Ingested 406000 rows...
# Ingested 407000 rows...
# Ingested 408000 rows...
# Ingested 409000 rows...
# Ingested 410000 rows...
# Ingested 411000 rows...
# Ingested 412000 rows...
# Ingested 413000 rows...
# Ingested 414000 rows...
# Ingested 415000 rows...
# Ingested 416000 rows...
# Ingested 417000 rows...
# Ingested 418000 rows...
# Ingested 419000 rows...
# Ingested 420000 rows...
# Ingested 421000 rows...
# Ingested 422000 rows...
# Ingested 423000 rows...
# Ingested 424000 rows...
# Ingested 425000 rows...
# Ingested 426000 rows...
# Ingested 427000 rows...
# Ingested 428000 rows...
# Ingested 429000 rows...
# Ingested 430000 rows...
# Ingested 431000 rows...
# Ingested 432000 rows...
# Ingested 433000 rows...
# Ingested 434000 rows...
# Ingested 435000 rows...
# Ingested 436000 rows...
# Ingested 437000 rows...
# Ingested 438000 rows...
# Ingested 439000 rows...
# Ingested 440000 rows...
# Ingested 441000 rows...
# Ingested 442000 rows...
# Ingested 443000 rows...
# Ingested 444000 rows...
# Ingested 445000 rows...
# Ingested 446000 rows...
# Ingested 447000 rows...
# Ingested 448000 rows...
# Ingested 449000 rows...
# Ingested 450000 rows...
# Ingested 451000 rows...
# Ingested 452000 rows...
# Ingested 453000 rows...
# Ingested 454000 rows...
# Ingested 455000 rows...
# Ingested 456000 rows...
# Ingested 457000 rows...
# Ingested 458000 rows...
# Ingested 459000 rows...
# Ingested 460000 rows...
# Ingested 461000 rows...
# Ingested 462000 rows...
# Ingested 463000 rows...
# Ingested 464000 rows...
# Ingested 465000 rows...
# Ingested 466000 rows...
# Ingested 467000 rows...
# Ingested 468000 rows...
# Ingested 469000 rows...
# Ingested 470000 rows...
# Ingested 471000 rows...
# Ingested 472000 rows...
# Ingested 473000 rows...
# Ingested 474000 rows...
# Ingested 475000 rows...
# Ingested 476000 rows...
# Ingested 477000 rows...
# Ingested 478000 rows...
# Ingested 479000 rows...
# Ingested 480000 rows...
# Ingested 481000 rows...
# Ingested 482000 rows...
# Ingested 483000 rows...
# Ingested 484000 rows...
# Ingested 485000 rows...
# Ingested 486000 rows...
# Ingested 487000 rows...
# Ingested 488000 rows...
# Ingested 489000 rows...
# Ingested 490000 rows...
# Ingested 491000 rows...
# Ingested 492000 rows...
# Ingested 493000 rows...
# Ingested 494000 rows...
# Ingested 495000 rows...
# Ingested 496000 rows...
# Ingested 497000 rows...
# Ingested 498000 rows...
# Ingested 499000 rows...
# Ingested 500000 rows...
# Ingested 501000 rows...
# Ingested 502000 rows...
# Ingested 503000 rows...
# Ingested 504000 rows...
# Ingested 505000 rows...
# Ingested 506000 rows...
# Ingested 507000 rows...
# Ingested 508000 rows...
# Ingested 509000 rows...
# Ingested 510000 rows...
# Ingested 511000 rows...
# Ingested 512000 rows...
# Ingested 513000 rows...
# Ingested 514000 rows...
# Ingested 515000 rows...
# Ingested 516000 rows...
# Ingested 517000 rows...
# Ingested 518000 rows...
# Ingested 519000 rows...
# Ingested 520000 rows...
# Ingested 521000 rows...
# Ingested 522000 rows...
# Ingested 523000 rows...
# Ingested 524000 rows...
# Ingested 525000 rows...
# Ingested 526000 rows...
# Ingested 527000 rows...
# Ingested 528000 rows...
# Ingested 529000 rows...
# Ingested 530000 rows...
# Ingested 531000 rows...
# Ingested 532000 rows...
# Ingested 533000 rows...
# Ingested 534000 rows...
# Ingested 535000 rows...
# Ingested 536000 rows...
# Ingested 537000 rows...
# Ingested 538000 rows...
# Ingested 539000 rows...
# Ingested 540000 rows...
# Ingested 541000 rows...
# Ingested 542000 rows...
# Ingested 543000 rows...
# Ingested 544000 rows...
# Ingested 545000 rows...
# Ingested 546000 rows...
# Ingested 547000 rows...
# Ingested 548000 rows...
# Ingested 549000 rows...
# Ingested 550000 rows...
# Ingested 551000 rows...
# Ingested 552000 rows...
# Ingested 553000 rows...
# Ingested 554000 rows...
# Ingested 555000 rows...
# Ingested 556000 rows...
# Ingested 557000 rows...
# Ingested 558000 rows...
# Ingested 559000 rows...
# Ingested 560000 rows...
# Ingested 561000 rows...
# Ingested 562000 rows...
# Ingested 563000 rows...
# Ingested 564000 rows...
# Ingested 565000 rows...
# Ingested 566000 rows...
# Ingested 567000 rows...
# Ingested 568000 rows...
# Ingested 569000 rows...
# Ingested 570000 rows...
# Ingested 571000 rows...
# Ingested 572000 rows...
# Ingested 573000 rows...
# Ingested 574000 rows...
# Ingested 575000 rows...
# Ingested 576000 rows...
# Ingested 577000 rows...
# Ingested 578000 rows...
# Ingested 579000 rows...
# Ingested 580000 rows...
# Ingested 581000 rows...
# Ingested 582000 rows...
# Ingested 583000 rows...
# Ingested 584000 rows...
# Ingested 585000 rows...
# Ingested 586000 rows...
# Ingested 587000 rows...
# Ingested 588000 rows...
# Ingested 589000 rows...
# Ingested 590000 rows...
# Ingested 591000 rows...
# Ingested 592000 rows...
# Ingested 593000 rows...
# Ingested 594000 rows...
# Ingested 595000 rows...
# Ingested 596000 rows...
# Ingested 597000 rows...
# Ingested 598000 rows...
# Ingested 599000 rows...
# Ingested 600000 rows...
# Ingested 601000 rows...
# Ingested 602000 rows...
# Ingested 603000 rows...
# Ingested 604000 rows...
# Ingested 605000 rows...
# Ingested 606000 rows...
# Ingested 607000 rows...
# Ingested 608000 rows...
# Ingested 609000 rows...
# Ingested 610000 rows...
# Ingested 611000 rows...
# Ingested 612000 rows...
# Ingested 613000 rows...
# Ingested 614000 rows...
# Ingested 615000 rows...
# Ingested 616000 rows...
# Ingested 617000 rows...
# Ingested 618000 rows...
# Ingested 619000 rows...
# Ingested 620000 rows...
# Ingested 621000 rows...
# Ingested 622000 rows...
# Ingested 623000 rows...
# Ingested 624000 rows...
# Ingested 625000 rows...
# Ingested 626000 rows...
# Ingested 627000 rows...
# Ingested 628000 rows...
# Ingested 629000 rows...
# Ingested 630000 rows...
# Ingested 631000 rows...
# Ingested 632000 rows...
# Ingested 633000 rows...
# Ingested 634000 rows...
# Ingested 635000 rows...
# Ingested 636000 rows...
# Ingested 637000 rows...
# Ingested 638000 rows...
# Ingested 639000 rows...
# Ingested 640000 rows...
# Ingested 641000 rows...
# Ingested 642000 rows...
# Ingested 643000 rows...
# Ingested 644000 rows...
# Ingested 645000 rows...
# Ingested 646000 rows...
# Ingested 647000 rows...
# Ingested 648000 rows...
# Ingested 649000 rows...
# Ingested 650000 rows...
# Ingested 651000 rows...
# Ingested 652000 rows...
# Ingested 653000 rows...
# Ingested 654000 rows...
# Ingested 655000 rows...
# Ingested 656000 rows...
# Ingested 657000 rows...
# Ingested 658000 rows...
# Ingested 659000 rows...
# Ingested 660000 rows...
# Ingested 661000 rows...
# Ingested 662000 rows...
# Ingested 663000 rows...
# Ingested 664000 rows...
# Ingested 665000 rows...
# Ingested 666000 rows...
# Ingested 667000 rows...
# Ingested 668000 rows...
# Ingested 669000 rows...
# Ingested 670000 rows...
# Ingested 671000 rows...
# Ingested 672000 rows...
# Ingested 673000 rows...
# Ingested 674000 rows...
# Ingested 675000 rows...
# Ingested 676000 rows...
# Ingested 677000 rows...
# Ingested 678000 rows...
# Ingested 679000 rows...
# Ingested 680000 rows...
# Ingested 681000 rows...
# Ingested 682000 rows...
# Ingested 683000 rows...
# Ingested 684000 rows...
# Ingested 685000 rows...
# Ingested 686000 rows...
# Ingested 687000 rows...
# Ingested 688000 rows...
# Ingested 689000 rows...
# Ingested 690000 rows...
# Ingested 691000 rows...
# Ingested 692000 rows...
# Ingested 693000 rows...
# Ingested 694000 rows...
# Ingested 695000 rows...
# Ingested 696000 rows...
# Ingested 697000 rows...
# Ingested 698000 rows...
# Ingested 699000 rows...
# Ingested 700000 rows...
# Ingested 701000 rows...
# Ingested 702000 rows...
# Ingested 703000 rows...
# Ingested 704000 rows...
# Ingested 705000 rows...
# Ingested 706000 rows...
# Ingested 707000 rows...
# Ingested 708000 rows...
# Ingested 709000 rows...
# Ingested 710000 rows...
# Ingested 711000 rows...
# Ingested 712000 rows...
# Ingested 713000 rows...
# Ingested 714000 rows...
# Ingested 715000 rows...
# Ingested 716000 rows...
# Ingested 717000 rows...
# Ingested 718000 rows...
# Ingested 719000 rows...
# Ingested 720000 rows...
# Ingested 721000 rows...
# Ingested 722000 rows...
# Ingested 723000 rows...
# Ingested 724000 rows...
# Ingested 725000 rows...
# Ingested 726000 rows...
# Ingested 727000 rows...
# Ingested 728000 rows...
# Ingested 729000 rows...
# Ingested 730000 rows...
# Ingested 731000 rows...
# Ingested 732000 rows...
# Ingested 733000 rows...
# Ingested 734000 rows...
# Ingested 735000 rows...
# Ingested 736000 rows...
# Ingested 737000 rows...
# Ingested 738000 rows...
# Ingested 739000 rows...
# Ingested 740000 rows...
# Ingested 741000 rows...
# Ingested 742000 rows...
# Ingested 743000 rows...
# Ingested 744000 rows...
# Ingested 745000 rows...
# Ingested 746000 rows...
# Ingested 747000 rows...
# Ingested 748000 rows...
# Ingested 749000 rows...
# Ingested 750000 rows...
# Ingested 751000 rows...
# Ingested 752000 rows...
# Ingested 753000 rows...
# Ingested 754000 rows...
# Ingested 755000 rows...
# Ingested 756000 rows...
# Ingested 757000 rows...
# Ingested 758000 rows...
# Ingested 759000 rows...
# Ingested 760000 rows...
# Ingested 761000 rows...
# Ingested 762000 rows...
# Ingested 763000 rows...
# Ingested 764000 rows...
# Ingested 765000 rows...
# Ingested 766000 rows...
# Ingested 767000 rows...
# Ingested 768000 rows...
# Ingested 769000 rows...
# Ingested 770000 rows...
# Ingested 771000 rows...
# Ingested 772000 rows...
# Ingested 773000 rows...
# Ingested 774000 rows...
# Ingested 775000 rows...
# Ingested 776000 rows...
# Ingested 777000 rows...
# Ingested 778000 rows...
# Ingested 779000 rows...
# Ingested 780000 rows...
# Ingested 781000 rows...
# Ingested 782000 rows...
# Ingested 783000 rows...
# Ingested 784000 rows...
# Ingested 785000 rows...
# Ingested 786000 rows...
# Ingested 787000 rows...
# Ingested 788000 rows...
# Ingested 789000 rows...
# Ingested 790000 rows...
# Ingested 791000 rows...
# Ingested 792000 rows...
# Ingested 793000 rows...
# Ingested 794000 rows...
# Ingested 795000 rows...
# Ingested 796000 rows...
# Ingested 797000 rows...
# Ingested 798000 rows...
# Ingested 799000 rows...
# Ingested 800000 rows...
# Ingested 801000 rows...
# Ingested 802000 rows...
# Ingested 803000 rows...
# Ingested 804000 rows...
# Ingested 805000 rows...
# Ingested 806000 rows...
# Ingested 807000 rows...
# Ingested 808000 rows...
# Ingested 809000 rows...
# Ingested 810000 rows...
# Ingested 811000 rows...
# Ingested 812000 rows...
# Ingested 813000 rows...
# Ingested 814000 rows...
# Ingested 815000 rows...
# Ingested 816000 rows...
# Ingested 817000 rows...
# Ingested 818000 rows...
# Ingested 819000 rows...
# Ingested 820000 rows...
# Ingested 821000 rows...
# Ingested 822000 rows...
# Ingested 823000 rows...
# Ingested 824000 rows...
# Ingested 825000 rows...
# Ingested 826000 rows...
# Ingested 827000 rows...
# Ingested 828000 rows...
# Ingested 829000 rows...
# Ingested 830000 rows...
# Ingested 831000 rows...
# Ingested 832000 rows...
# Ingested 833000 rows...
# Ingested 834000 rows...
# Ingested 835000 rows...
# Ingested 836000 rows...
# Ingested 837000 rows...
# Ingested 838000 rows...
# Ingested 839000 rows...
# Ingested 840000 rows...
# Ingested 841000 rows...
# Ingested 842000 rows...
# Ingested 843000 rows...
# Ingested 844000 rows...
# Ingested 845000 rows...
# Ingested 846000 rows...
# Ingested 847000 rows...
# Ingested 848000 rows...
# Ingested 849000 rows...
# Ingested 850000 rows...
# Ingested 851000 rows...
# Ingested 852000 rows...
# Ingested 853000 rows...
# Ingested 854000 rows...
# Ingested 855000 rows...
# Ingested 856000 rows...
# Ingested 857000 rows...
# Ingested 858000 rows...
# Ingested 859000 rows...
# Ingested 860000 rows...
# Ingested 861000 rows...
# Ingested 862000 rows...
# Ingested 863000 rows...
# Ingested 864000 rows...
# Ingested 865000 rows...
# Ingested 866000 rows...
# Ingested 867000 rows...
# Ingested 868000 rows...
# Ingested 869000 rows...
# Ingested 870000 rows...
# Ingested 871000 rows...
# Ingested 872000 rows...
# Ingested 873000 rows...
# Ingested 874000 rows...
# Ingested 875000 rows...
# Ingested 876000 rows...
# Ingested 877000 rows...
# Ingested 878000 rows...
# Ingested 879000 rows...
# Ingested 880000 rows...
# Ingested 881000 rows...
# Ingested 882000 rows...
# Ingested 883000 rows...
# Ingested 884000 rows...
# Ingested 885000 rows...
# Ingested 886000 rows...
# Ingested 887000 rows...
# Ingested 888000 rows...
# Ingested 889000 rows...
# Ingested 890000 rows...
# Ingested 891000 rows...
# Ingested 892000 rows...
# Ingested 893000 rows...
# Ingested 894000 rows...
# Ingested 895000 rows...
# Ingested 896000 rows...
# Ingested 897000 rows...
# Ingested 898000 rows...
# Ingested 899000 rows...
# Ingested 900000 rows...
# Ingested 901000 rows...
# Ingested 902000 rows...
# Ingested 903000 rows...
# Ingested 904000 rows...
# Ingested 905000 rows...
# Ingested 906000 rows...
# Ingested 907000 rows...
# Ingested 908000 rows...
# Ingested 909000 rows...
# Ingested 910000 rows...
# Ingested 911000 rows...
# Ingested 912000 rows...
# Ingested 913000 rows...
# Ingested 914000 rows...
# Ingested 915000 rows...
# Ingested 916000 rows...
# Ingested 917000 rows...
# Ingested 918000 rows...
# Ingested 919000 rows...
# Ingested 920000 rows...
# Ingested 921000 rows...
# Ingested 922000 rows...
# Ingested 923000 rows...
# Ingested 924000 rows...
# Ingested 925000 rows...
# Ingested 926000 rows...
# Ingested 927000 rows...
# Ingested 928000 rows...
# Ingested 929000 rows...
# Ingested 930000 rows...
# Ingested 931000 rows...
# Ingested 932000 rows...
# Ingested 933000 rows...
# Ingested 934000 rows...
# Ingested 935000 rows...
# Ingested 936000 rows...
# Ingested 937000 rows...
# Ingested 938000 rows...
# Ingested 939000 rows...
# Ingested 940000 rows...
# Ingested 941000 rows...
# Ingested 942000 rows...
# Ingested 943000 rows...
# Ingested 944000 rows...
# Ingested 945000 rows...
# Ingested 946000 rows...
# Ingested 947000 rows...
# Ingested 948000 rows...
# Ingested 949000 rows...
# Ingested 950000 rows...
# Ingested 951000 rows...
# Ingested 952000 rows...
# Ingested 953000 rows...
# Ingested 954000 rows...
# Ingested 955000 rows...
# Ingested 956000 rows...
# Ingested 957000 rows...
# Ingested 958000 rows...
# Ingested 959000 rows...
# Ingested 960000 rows...
# Ingested 961000 rows...
# Ingested 962000 rows...
# Ingested 963000 rows...
# Ingested 964000 rows...
# Ingested 965000 rows...
# Ingested 966000 rows...
# Ingested 967000 rows...
# Ingested 968000 rows...
# Ingested 969000 rows...
# Ingested 970000 rows...
# Ingested 971000 rows...
# Ingested 972000 rows...
# Ingested 973000 rows...
# Ingested 974000 rows...
# Ingested 975000 rows...
# Ingested 976000 rows...
# Ingested 977000 rows...
# Ingested 978000 rows...
# Ingested 979000 rows...
# Ingested 980000 rows...
# Ingested 981000 rows...
# Ingested 982000 rows...
# Ingested 983000 rows...
# Ingested 984000 rows...
# Ingested 985000 rows...
# Ingested 986000 rows...
# Ingested 987000 rows...
# Ingested 988000 rows...
# Ingested 989000 rows...
# Ingested 990000 rows...
# Ingested 991000 rows...
# Ingested 992000 rows...
# Ingested 993000 rows...
# Ingested 994000 rows...
# Ingested 995000 rows...
# Ingested 996000 rows...
# Ingested 997000 rows...
# Ingested 998000 rows...
# Ingested 999000 rows...
# Ingested 1000000 rows...
# Ingested 1001000 rows...
# Ingested 1002000 rows...
# Ingested 1003000 rows...
# Ingested 1004000 rows...
# Ingested 1005000 rows...
# Ingested 1006000 rows...
# Ingested 1007000 rows...
# Ingested 1008000 rows...
# Ingested 1009000 rows...
# Ingested 1010000 rows...
# Ingested 1011000 rows...
# Ingested 1012000 rows...
# Ingested 1013000 rows...
# Ingested 1014000 rows...
# Ingested 1015000 rows...
# Ingested 1016000 rows...
# Ingested 1017000 rows...
# Ingested 1018000 rows...
# Ingested 1019000 rows...
# Ingested 1020000 rows...
# Ingested 1021000 rows...
# Ingested 1022000 rows...
# Ingested 1023000 rows...
# Ingested 1024000 rows...
# Ingested 1025000 rows...
# Ingested 1026000 rows...
# Ingested 1027000 rows...
# Ingested 1028000 rows...
# Ingested 1029000 rows...
# Ingested 1030000 rows...
# Ingested 1031000 rows...
# Ingested 1032000 rows...
# Ingested 1033000 rows...
# Ingested 1034000 rows...
# Ingested 1035000 rows...
# Ingested 1036000 rows...
# Ingested 1037000 rows...
# Ingested 1038000 rows...
# Ingested 1039000 rows...
# Ingested 1040000 rows...
# Ingested 1041000 rows...
# Ingested 1042000 rows...
# Ingested 1043000 rows...
# Ingested 1044000 rows...
# Ingested 1045000 rows...
# Ingested 1046000 rows...
# Ingested 1047000 rows...
# Ingested 1048000 rows...
# Ingested 1049000 rows...
# Ingested 1050000 rows...
# Ingested 1051000 rows...
# Ingested 1052000 rows...
# Ingested 1053000 rows...
# Ingested 1054000 rows...
# Ingested 1055000 rows...
# Ingested 1056000 rows...
# Ingested 1057000 rows...
# Ingested 1058000 rows...
# Ingested 1059000 rows...
# Ingested 1060000 rows...
# Ingested 1061000 rows...
# Ingested 1062000 rows...
# Ingested 1063000 rows...
# Ingested 1064000 rows...
# Ingested 1065000 rows...
# Ingested 1066000 rows...
# Ingested 1067000 rows...
# Ingested 1068000 rows...
# Ingested 1069000 rows...
# Ingested 1070000 rows...
# Ingested 1071000 rows...
# Ingested 1072000 rows...
# Ingested 1073000 rows...
# Ingested 1074000 rows...
# Ingested 1075000 rows...
# Ingested 1076000 rows...
# Ingested 1077000 rows...
# Ingested 1078000 rows...
# Ingested 1079000 rows...
# Ingested 1080000 rows...
# Ingested 1081000 rows...
# Ingested 1082000 rows...
# Ingested 1083000 rows...
# Ingested 1084000 rows...
# Ingested 1085000 rows...
# Ingested 1086000 rows...
# Ingested 1087000 rows...
# Ingested 1088000 rows...
# Ingested 1089000 rows...
# Ingested 1090000 rows...
# Ingested 1091000 rows...
# Ingested 1092000 rows...
# Ingested 1093000 rows...
# Ingested 1094000 rows...
# Ingested 1095000 rows...
# Ingested 1096000 rows...
# Ingested 1097000 rows...
# Ingested 1098000 rows...
# Ingested 1099000 rows...
# Ingested 1100000 rows...
# Ingested 1101000 rows...
# Ingested 1102000 rows...
# Ingested 1103000 rows...
# Ingested 1104000 rows...
# Ingested 1105000 rows...
# Ingested 1106000 rows...
# Ingested 1107000 rows...
# Ingested 1108000 rows...
# Ingested 1109000 rows...
# Ingested 1110000 rows...
# Ingested 1111000 rows...
# Ingested 1112000 rows...
# Ingested 1113000 rows...
# Ingested 1114000 rows...
# Ingested 1115000 rows...
# Ingested 1116000 rows...
# Ingested 1117000 rows...
# Ingested 1118000 rows...
# Ingested 1119000 rows...
# Ingested 1120000 rows...
# Ingested 1121000 rows...
# Ingested 1122000 rows...
# Ingested 1123000 rows...
# Ingested 1124000 rows...
# Ingested 1125000 rows...
# Ingested 1126000 rows...
# Ingested 1127000 rows...
# Ingested 1128000 rows...
# Ingested 1129000 rows...
# Ingested 1130000 rows...
# Ingested 1131000 rows...
# Ingested 1132000 rows...
# Ingested 1133000 rows...
# Ingested 1134000 rows...
# Ingested 1135000 rows...
# Ingested 1136000 rows...
# Ingested 1137000 rows...
# Ingested 1138000 rows...
# Ingested 1139000 rows...
# Ingested 1140000 rows...
# Ingested 1141000 rows...
# Ingested 1142000 rows...
# Ingested 1143000 rows...
# Ingested 1144000 rows...
# Ingested 1145000 rows...
# Ingested 1146000 rows...
# Ingested 1147000 rows...
# Ingested 1148000 rows...
# Ingested 1149000 rows...
# Ingested 1150000 rows...
# Ingested 1151000 rows...
# Ingested 1152000 rows...
# Ingested 1153000 rows...
# Ingested 1154000 rows...
# Ingested 1155000 rows...
# Ingested 1156000 rows...
# Ingested 1157000 rows...
# Ingested 1158000 rows...
# Ingested 1159000 rows...
# Ingested 1160000 rows...
# Ingested 1161000 rows...
# Ingested 1162000 rows...
# Ingested 1163000 rows...
# Ingested 1164000 rows...
# Ingested 1165000 rows...
# Ingested 1166000 rows...
# Ingested 1167000 rows...
# Ingested 1168000 rows...
# Ingested 1169000 rows...
# Ingested 1170000 rows...
# Ingested 1171000 rows...
# Ingested 1172000 rows...
# Ingested 1173000 rows...
# Ingested 1174000 rows...
# Ingested 1175000 rows...
# Ingested 1176000 rows...
# Ingested 1177000 rows...
# Ingested 1178000 rows...
# Ingested 1179000 rows...
# Ingested 1180000 rows...
# Ingested 1181000 rows...
# Ingested 1182000 rows...
# Ingested 1183000 rows...
# Ingested 1184000 rows...
# Ingested 1185000 rows...
# Ingested 1186000 rows...
# Ingested 1187000 rows...
# Ingested 1188000 rows...
# Ingested 1189000 rows...
# Ingested 1190000 rows...
# Ingested 1191000 rows...
# Ingested 1192000 rows...
# Ingested 1193000 rows...
# Ingested 1194000 rows...
# Ingested 1195000 rows...
# Ingested 1196000 rows...
# Ingested 1197000 rows...
# Ingested 1198000 rows...
# Ingested 1199000 rows...
# Ingested 1200000 rows...
# Ingested 1201000 rows...
# Ingested 1202000 rows...
# Ingested 1203000 rows...
# Ingested 1204000 rows...
# Ingested 1205000 rows...
# Ingested 1206000 rows...
# Ingested 1207000 rows...
# Ingested 1208000 rows...
# Ingested 1209000 rows...
# Ingested 1210000 rows...
# Ingested 1211000 rows...
# Ingested 1212000 rows...
# Ingested 1213000 rows...
# Ingested 1214000 rows...
# Ingested 1215000 rows...
# Ingested 1216000 rows...
# Ingested 1217000 rows...
# Ingested 1218000 rows...
# Ingested 1219000 rows...
# Ingested 1220000 rows...
# Ingested 1221000 rows...
# Ingested 1222000 rows...
# Ingested 1223000 rows...
# Ingested 1224000 rows...
# Ingested 1225000 rows...
# Ingested 1226000 rows...
# Ingested 1227000 rows...
# Ingested 1228000 rows...
# Ingested 1229000 rows...
# Ingested 1230000 rows...
# Ingested 1231000 rows...
# Ingested 1232000 rows...
# Ingested 1233000 rows...
# Ingested 1234000 rows...
# Ingested 1235000 rows...
# Ingested 1236000 rows...
# Ingested 1237000 rows...
# Ingested 1238000 rows...
# Ingested 1239000 rows...
# Ingested 1240000 rows...
# Ingested 1241000 rows...
# Ingested 1242000 rows...
# Ingested 1243000 rows...
# Ingested 1244000 rows...
# Ingested 1245000 rows...
# Ingested 1246000 rows...
# Ingested 1247000 rows...
# Ingested 1248000 rows...
# Ingested 1249000 rows...
# Ingested 1250000 rows...
# Ingested 1251000 rows...
# Ingested 1252000 rows...
# Ingested 1253000 rows...
# Ingested 1254000 rows...
# Ingested 1255000 rows...
# Ingested 1256000 rows...
# Ingested 1257000 rows...
# Ingested 1258000 rows...
# Ingested 1259000 rows...
# Ingested 1260000 rows...
# Ingested 1261000 rows...
# Ingested 1262000 rows...
# Ingested 1263000 rows...
# Ingested 1264000 rows...
# Ingested 1265000 rows...
# Ingested 1266000 rows...
# Ingested 1267000 rows...
# Ingested 1268000 rows...
# Ingested 1269000 rows...
# Ingested 1270000 rows...
# Ingested 1271000 rows...
# Ingested 1272000 rows...
# Ingested 1273000 rows...
# Ingested 1274000 rows...
# Ingested 1275000 rows...
# Ingested 1276000 rows...
# Ingested 1277000 rows...
# Ingested 1278000 rows...
# Ingested 1279000 rows...
# Ingested 1280000 rows...
# Ingested 1281000 rows...
# Ingested 1282000 rows...
# Ingested 1283000 rows...
# Ingested 1284000 rows...
# Ingested 1285000 rows...
# Ingested 1286000 rows...
# Ingested 1287000 rows...
# Ingested 1288000 rows...
# Ingested 1289000 rows...
# Ingested 1290000 rows...
# Ingested 1291000 rows...
# Ingested 1292000 rows...
# Ingested 1293000 rows...
# Ingested 1294000 rows...
# Ingested 1295000 rows...
# Ingested 1296000 rows...
# Ingested 1297000 rows...
# Ingested 1298000 rows...
# Ingested 1299000 rows...
# Ingested 1300000 rows...
# Ingested 1301000 rows...
# Ingested 1302000 rows...
# Ingested 1303000 rows...
# Ingested 1304000 rows...
# Ingested 1305000 rows...
# Ingested 1306000 rows...
# Ingested 1307000 rows...
# Ingested 1308000 rows...
# Ingested 1309000 rows...
# Ingested 1310000 rows...
# Ingested 1311000 rows...
# Ingested 1312000 rows...
# Ingested 1313000 rows...
# Ingested 1314000 rows...
# Ingested 1315000 rows...
# Ingested 1316000 rows...
# Ingested 1317000 rows...
# Ingested 1318000 rows...
# Ingested 1319000 rows...
# Ingested 1320000 rows...
# Ingested 1321000 rows...
# Ingested 1322000 rows...
# Ingested 1323000 rows...
# Ingested 1324000 rows...
# Ingested 1325000 rows...
# Ingested 1326000 rows...
# Ingested 1327000 rows...
# Ingested 1328000 rows...
# Ingested 1329000 rows...
# Ingested 1330000 rows...
# Ingested 1331000 rows...
# Ingested 1332000 rows...
# Ingested 1333000 rows...
# Ingested 1334000 rows...
# Ingested 1335000 rows...
# Ingested 1336000 rows...
# Ingested 1337000 rows...
# Ingested 1338000 rows...
# Ingested 1339000 rows...
# Ingested 1340000 rows...
# Ingested 1341000 rows...
# Ingested 1342000 rows...
# Ingested 1343000 rows...
# Ingested 1344000 rows...
# Ingested 1345000 rows...
# Ingested 1346000 rows...
# Ingested 1347000 rows...
# Ingested 1348000 rows...
# Ingested 1349000 rows...
# Ingested 1350000 rows...
# Ingested 1351000 rows...
# Ingested 1352000 rows...
# Ingested 1353000 rows...
# Ingested 1354000 rows...
# Ingested 1355000 rows...
# Ingested 1356000 rows...
# Ingested 1357000 rows...
# Ingested 1358000 rows...
# Ingested 1359000 rows...
# Ingested 1360000 rows...
# Ingested 1361000 rows...
# Ingested 1362000 rows...
# Ingested 1363000 rows...
# Ingested 1364000 rows...
# Ingested 1365000 rows...
# Ingested 1366000 rows...
# Ingested 1367000 rows...
# Ingested 1368000 rows...
# Ingested 1369000 rows...
# Ingested 1370000 rows...
# Ingested 1371000 rows...
# Ingested 1372000 rows...
# Ingested 1373000 rows...
# Ingested 1374000 rows...
# Ingested 1375000 rows...
# Ingested 1376000 rows...
# Ingested 1377000 rows...
# Ingested 1378000 rows...
# Ingested 1379000 rows...
# Ingested 1380000 rows...
# Ingested 1381000 rows...
# Ingested 1382000 rows...
# Ingested 1383000 rows...
# Ingested 1384000 rows...
# Ingested 1385000 rows...
# Ingested 1386000 rows...
# Ingested 1387000 rows...
# Ingested 1388000 rows...
# Ingested 1389000 rows...
# Ingested 1390000 rows...
# Ingested 1391000 rows...
# Ingested 1392000 rows...
# Ingested 1393000 rows...
# Ingested 1394000 rows...
# Ingested 1395000 rows...
# Ingested 1396000 rows...
# Ingested 1397000 rows...
# Ingested 1398000 rows...
# Ingested 1399000 rows...
# Ingested 1400000 rows...
# Ingested 1401000 rows...
# Ingested 1402000 rows...
# Ingested 1403000 rows...
# Ingested 1404000 rows...
# Ingested 1405000 rows...
# Ingested 1406000 rows...
# Ingested 1407000 rows...
# Ingested 1408000 rows...
# Ingested 1409000 rows...
# Ingested 1410000 rows...
# Ingested 1411000 rows...
# Ingested 1412000 rows...
# Ingested 1413000 rows...
# Ingested 1414000 rows...
# Ingested 1415000 rows...
# Ingested 1416000 rows...
# Ingested 1417000 rows...
# Ingested 1418000 rows...
# Ingested 1419000 rows...
# Ingested 1420000 rows...
# Ingested 1421000 rows...
# Ingested 1422000 rows...
# Ingested 1423000 rows...
# Ingested 1424000 rows...
# Ingested 1425000 rows...
# Ingested 1426000 rows...
# Ingested 1427000 rows...
# Ingested 1428000 rows...
# Ingested 1429000 rows...
# Ingested 1430000 rows...
# Ingested 1431000 rows...
# Ingested 1432000 rows...
# Ingested 1433000 rows...
# Ingested 1434000 rows...
# Ingested 1435000 rows...
# Ingested 1436000 rows...
# Ingested 1437000 rows...
# Ingested 1438000 rows...
# Ingested 1439000 rows...
# Ingested 1440000 rows...
# Ingested 1441000 rows...
# Ingested 1442000 rows...
# Ingested 1443000 rows...
# Ingested 1444000 rows...
# Ingested 1445000 rows...
# Ingested 1446000 rows...
# Ingested 1447000 rows...
# Ingested 1448000 rows...
# Ingested 1449000 rows...
# Ingested 1450000 rows...
# Ingested 1451000 rows...
# Ingested 1452000 rows...
# Ingested 1453000 rows...
# Ingested 1454000 rows...
# Ingested 1455000 rows...
# Ingested 1456000 rows...
# Ingested 1457000 rows...
# Ingested 1458000 rows...
# Ingested 1459000 rows...
# Ingested 1460000 rows...
# Ingested 1461000 rows...
# Ingested 1462000 rows...
# Ingested 1463000 rows...
# Ingested 1464000 rows...
# Ingested 1465000 rows...
# Ingested 1466000 rows...
# Ingested 1467000 rows...
# Ingested 1468000 rows...
# Ingested 1469000 rows...
# Ingested 1470000 rows...
# Ingested 1471000 rows...
# Ingested 1472000 rows...
# Ingested 1473000 rows...
# Ingested 1474000 rows...
# Ingested 1475000 rows...
# Ingested 1476000 rows...
# Ingested 1477000 rows...
# Ingested 1478000 rows...
# Ingested 1479000 rows...
# Ingested 1480000 rows...
# Ingested 1481000 rows...
# Ingested 1482000 rows...
# Ingested 1483000 rows...
# Ingested 1484000 rows...
# Ingested 1485000 rows...
# Ingested 1486000 rows...
# Ingested 1487000 rows...
# Ingested 1488000 rows...
# Ingested 1489000 rows...
# Ingested 1490000 rows...
# Ingested 1491000 rows...
# Ingested 1492000 rows...
# Ingested 1493000 rows...
# Ingested 1494000 rows...
# Ingested 1495000 rows...
# Ingested 1496000 rows...
# Ingested 1497000 rows...
# Ingested 1498000 rows...
# Ingested 1499000 rows...
# Ingested 1500000 rows...
# Ingested 1501000 rows...
# Ingested 1502000 rows...
# Ingested 1503000 rows...
# Ingested 1504000 rows...
# Ingested 1505000 rows...
# Ingested 1506000 rows...
# Ingested 1507000 rows...
# Ingested 1508000 rows...
# Ingested 1509000 rows...
# Ingested 1510000 rows...
# Ingested 1511000 rows...
# Ingested 1512000 rows...
# Ingested 1513000 rows...
# Ingested 1514000 rows...
# Ingested 1515000 rows...
# Ingested 1516000 rows...
# Ingested 1517000 rows...
# Ingested 1518000 rows...
# Ingested 1519000 rows...
# Ingested 1520000 rows...
# Ingested 1521000 rows...
# Ingested 1522000 rows...
# Ingested 1523000 rows...
# Ingested 1524000 rows...
# Ingested 1525000 rows...
# Ingested 1526000 rows...
# Ingested 1527000 rows...
# Ingested 1528000 rows...
# Ingested 1529000 rows...
# Ingested 1530000 rows...
# Ingested 1531000 rows...
# Ingested 1532000 rows...
# Ingested 1533000 rows...
# Ingested 1534000 rows...
# Ingested 1535000 rows...
# Ingested 1536000 rows...
# Ingested 1537000 rows...
# Ingested 1538000 rows...
# Ingested 1539000 rows...
# Ingested 1540000 rows...
# Ingested 1541000 rows...
# Ingested 1542000 rows...
# Ingested 1543000 rows...
# Ingested 1544000 rows...
# Ingested 1545000 rows...
# Ingested 1546000 rows...
# Ingested 1547000 rows...
# Ingested 1548000 rows...
# Ingested 1549000 rows...
# Ingested 1550000 rows...
# Ingested 1551000 rows...
# Ingested 1552000 rows...
# Ingested 1553000 rows...
# Ingested 1554000 rows...
# Ingested 1555000 rows...
# Ingested 1556000 rows...
# Ingested 1557000 rows...
# Ingested 1558000 rows...
# Ingested 1559000 rows...
# Ingested 1560000 rows...
# Ingested 1561000 rows...
# Ingested 1562000 rows...
# Ingested 1563000 rows...
# Ingested 1564000 rows...
# Ingested 1565000 rows...
# Ingested 1566000 rows...
# Ingested 1567000 rows...
# Ingested 1568000 rows...
# Ingested 1569000 rows...
# Ingested 1570000 rows...
# Ingested 1571000 rows...
# Ingested 1572000 rows...
# Ingested 1573000 rows...
# Ingested 1574000 rows...
# Ingested 1575000 rows...
# Ingested 1576000 rows...
# Ingested 1577000 rows...
# Ingested 1578000 rows...
# Ingested 1579000 rows...
# Ingested 1580000 rows...
# Ingested 1581000 rows...
# Ingested 1582000 rows...
# Ingested 1583000 rows...
# Ingested 1584000 rows...
# Ingested 1585000 rows...
# Ingested 1586000 rows...
# Ingested 1587000 rows...
# Ingested 1588000 rows...
# Ingested 1589000 rows...
# Ingested 1590000 rows...
# Ingested 1591000 rows...
# Ingested 1592000 rows...
# Ingested 1593000 rows...
# Ingested 1594000 rows...
# Ingested 1595000 rows...
# Ingested 1596000 rows...
# Ingested 1597000 rows...
# Ingested 1598000 rows...
# Ingested 1599000 rows...
# Ingested 1600000 rows...
# Ingested 1601000 rows...
# Ingested 1602000 rows...
# Ingested 1603000 rows...
# Ingested 1604000 rows...
# Ingested 1605000 rows...
# Ingested 1606000 rows...
# Ingested 1607000 rows...
# Ingested 1608000 rows...
# Ingested 1609000 rows...
# Ingested 1610000 rows...
# Ingested 1611000 rows...
# Ingested 1612000 rows...
# Ingested 1613000 rows...
# Ingested 1614000 rows...
# Ingested 1615000 rows...
# Ingested 1616000 rows...
# Ingested 1617000 rows...
# Ingested 1618000 rows...
# Ingested 1619000 rows...
# Ingested 1620000 rows...
# Ingested 1621000 rows...
# Ingested 1622000 rows...
# Ingested 1623000 rows...
# Ingested 1624000 rows...
# Ingested 1625000 rows...
# Ingested 1626000 rows...
# Ingested 1627000 rows...
# Ingested 1628000 rows...
# Ingested 1629000 rows...
# Ingested 1630000 rows...
# Ingested 1631000 rows...
# Ingested 1632000 rows...
# Ingested 1633000 rows...
# Ingested 1634000 rows...
# Ingested 1635000 rows...
# Ingested 1636000 rows...
# Ingested 1637000 rows...
# Ingested 1638000 rows...
# Ingested 1639000 rows...
# Ingested 1640000 rows...
# Ingested 1641000 rows...
# Ingested 1642000 rows...
# Ingested 1643000 rows...
# Ingested 1644000 rows...
# Ingested 1645000 rows...
# Ingested 1646000 rows...
# Ingested 1647000 rows...
# Ingested 1648000 rows...
# Ingested 1649000 rows...
# Ingested 1650000 rows...
# Ingested 1651000 rows...
# Ingested 1652000 rows...
# Ingested 1653000 rows...
# Ingested 1654000 rows...
# Ingested 1655000 rows...
# Ingested 1656000 rows...
# Ingested 1657000 rows...
# Ingested 1658000 rows...
# Ingested 1659000 rows...
# Ingested 1660000 rows...
# Ingested 1661000 rows...
# Ingested 1662000 rows...
# Ingested 1663000 rows...
# Ingested 1664000 rows...
# Ingested 1665000 rows...
# Ingested 1666000 rows...
# Ingested 1667000 rows...
# Ingested 1668000 rows...
# Ingested 1669000 rows...
# Ingested 1670000 rows...
# Ingested 1671000 rows...
# Ingested 1672000 rows...
# Ingested 1673000 rows...
# Ingested 1674000 rows...
# Ingested 1675000 rows...
# Ingested 1676000 rows...
# Ingested 1677000 rows...
# Ingested 1678000 rows...
# Ingested 1679000 rows...
# Ingested 1680000 rows...
# Ingested 1681000 rows...
# Ingested 1682000 rows...
# Ingested 1683000 rows...
# Ingested 1684000 rows...
# Ingested 1685000 rows...
# Ingested 1686000 rows...
# Ingested 1687000 rows...
# Ingested 1688000 rows...
# Ingested 1689000 rows...
# Ingested 1690000 rows...
# Ingested 1691000 rows...
# Ingested 1692000 rows...
# Ingested 1693000 rows...
# Ingested 1694000 rows...
# Ingested 1695000 rows...
# Ingested 1696000 rows...
# Ingested 1697000 rows...
# Ingested 1698000 rows...
# Ingested 1699000 rows...
# Ingested 1700000 rows...
# Ingested 1701000 rows...
# Ingested 1702000 rows...
# Ingested 1703000 rows...
# Ingested 1704000 rows...
# Ingested 1705000 rows...
# Ingested 1706000 rows...
# Ingested 1707000 rows...
# Ingested 1708000 rows...
# Ingested 1709000 rows...
# Ingested 1710000 rows...
# Ingested 1711000 rows...
# Ingested 1712000 rows...
# Ingested 1713000 rows...
# Ingested 1714000 rows...
# Ingested 1715000 rows...
# Ingested 1716000 rows...
# Ingested 1717000 rows...
# Ingested 1718000 rows...
# Ingested 1719000 rows...
# Ingested 1720000 rows...
# Ingested 1721000 rows...
# Ingested 1722000 rows...
# Ingested 1723000 rows...
# Ingested 1724000 rows...
# Ingested 1725000 rows...
# Ingested 1726000 rows...
# Ingested 1727000 rows...
# Ingested 1728000 rows...
# Ingested 1729000 rows...
# Ingested 1730000 rows...
# Ingested 1731000 rows...
# Ingested 1732000 rows...
# Ingested 1733000 rows...
# Ingested 1734000 rows...
# Ingested 1735000 rows...
# Ingested 1736000 rows...
# Ingested 1737000 rows...
# Ingested 1738000 rows...
# Ingested 1739000 rows...
# Ingested 1740000 rows...
# Ingested 1741000 rows...
# Ingested 1742000 rows...
# Ingested 1743000 rows...
# Ingested 1744000 rows...
# Ingested 1745000 rows...
# Ingested 1746000 rows...
# Ingested 1747000 rows...
# Ingested 1748000 rows...
# Ingested 1749000 rows...
# Ingested 1750000 rows...
# Ingested 1751000 rows...
# Ingested 1752000 rows...
# Ingested 1753000 rows...
# Ingested 1754000 rows...
# Ingested 1755000 rows...
# Ingested 1756000 rows...
# Ingested 1757000 rows...
# Ingested 1758000 rows...
# Ingested 1759000 rows...
# Ingested 1760000 rows...
# Ingested 1761000 rows...
# Ingested 1762000 rows...
# Ingested 1763000 rows...
# Ingested 1764000 rows...
# Ingested 1765000 rows...
# Ingested 1766000 rows...
# Ingested 1767000 rows...
# Ingested 1768000 rows...
# Ingested 1769000 rows...
# Ingested 1770000 rows...
# Ingested 1771000 rows...
# Ingested 1772000 rows...
# Ingested 1773000 rows...
# Ingested 1774000 rows...
# Ingested 1775000 rows...
# Ingested 1776000 rows...
# Ingested 1777000 rows...
# Ingested 1778000 rows...
# Ingested 1779000 rows...
# Ingested 1780000 rows...
# Ingested 1781000 rows...
# Ingested 1782000 rows...
# Ingested 1783000 rows...
# Ingested 1784000 rows...
# Ingested 1785000 rows...
# Ingested 1786000 rows...
# Ingested 1787000 rows...
# Ingested 1788000 rows...
# Ingested 1789000 rows...
# Ingested 1790000 rows...
# Ingested 1791000 rows...
# Ingested 1792000 rows...
# Ingested 1793000 rows...
# Ingested 1794000 rows...
# Ingested 1795000 rows...
# Ingested 1796000 rows...
# Ingested 1797000 rows...
# Ingested 1798000 rows...
# Ingested 1799000 rows...
# Ingested 1800000 rows...
# Ingested 1801000 rows...
# Ingested 1802000 rows...
# Ingested 1803000 rows...
# Ingested 1804000 rows...
# Ingested 1805000 rows...
# Ingested 1806000 rows...
# Ingested 1807000 rows...
# Ingested 1808000 rows...
# Ingested 1809000 rows...
# Ingested 1810000 rows...
# Ingested 1811000 rows...
# Ingested 1812000 rows...
# Ingested 1813000 rows...
# Ingested 1814000 rows...
# Ingested 1815000 rows...
# Ingested 1816000 rows...
# Ingested 1817000 rows...
# Ingested 1818000 rows...
# Ingested 1819000 rows...
# Ingested 1820000 rows...
# Ingested 1821000 rows...
# Ingested 1822000 rows...
# Ingested 1823000 rows...
# Ingested 1824000 rows...
# Ingested 1825000 rows...
# Ingested 1826000 rows...
# Ingested 1827000 rows...
# Ingested 1828000 rows...
# Ingested 1829000 rows...
# Ingested 1830000 rows...
# Ingested 1831000 rows...
# Ingested 1832000 rows...
# Ingested 1833000 rows...
# Ingested 1834000 rows...
# Ingested 1835000 rows...
# Ingested 1836000 rows...
# Ingested 1837000 rows...
# Ingested 1838000 rows...
# Ingested 1839000 rows...
# Ingested 1840000 rows...
# Ingested 1841000 rows...
# Ingested 1842000 rows...
# Ingested 1843000 rows...
# Ingested 1844000 rows...
# Ingested 1845000 rows...
# Ingested 1846000 rows...
# Ingested 1847000 rows...
# Ingested 1848000 rows...
# Ingested 1849000 rows...
# Ingested 1850000 rows...
# Ingested 1851000 rows...
# Ingested 1852000 rows...
# Ingested 1853000 rows...
# Ingested 1854000 rows...
# Ingested 1855000 rows...
# Ingested 1856000 rows...
# Ingested 1857000 rows...
# Ingested 1858000 rows...
# Ingested 1859000 rows...
# Ingested 1860000 rows...
# Ingested 1861000 rows...
# Ingested 1862000 rows...
# Ingested 1863000 rows...
# Ingested 1864000 rows...
# Ingested 1865000 rows...
# Ingested 1866000 rows...
# Ingested 1867000 rows...
# Ingested 1868000 rows...
# Ingested 1869000 rows...
# Ingested 1870000 rows...
# Ingested 1871000 rows...
# Ingested 1872000 rows...
# Ingested 1873000 rows...
# Ingested 1874000 rows...
# Ingested 1875000 rows...
# Ingested 1876000 rows...
# Ingested 1877000 rows...
# Ingested 1878000 rows...
# Ingested 1879000 rows...
# Ingested 1880000 rows...
# Ingested 1881000 rows...
# Ingested 1882000 rows...
# Ingested 1883000 rows...
# Ingested 1884000 rows...
# Ingested 1885000 rows...
# Ingested 1886000 rows...
# Ingested 1887000 rows...
# Ingested 1888000 rows...
# Ingested 1889000 rows...
# Ingested 1890000 rows...
# Ingested 1891000 rows...
# Ingested 1892000 rows...
# Ingested 1893000 rows...
# Ingested 1894000 rows...
# Ingested 1895000 rows...
# Ingested 1896000 rows...
# Ingested 1897000 rows...
# Ingested 1898000 rows...
# Ingested 1899000 rows...
# Ingested 1900000 rows...
# Ingested 1901000 rows...
# Ingested 1902000 rows...
# Ingested 1903000 rows...
# Ingested 1904000 rows...
# Ingested 1905000 rows...
# Ingested 1906000 rows...
# Ingested 1907000 rows...
# Ingested 1908000 rows...
# Ingested 1909000 rows...
# Ingested 1910000 rows...
# Ingested 1911000 rows...
# Ingested 1912000 rows...
# Ingested 1913000 rows...
# Ingested 1914000 rows...
# Ingested 1915000 rows...
# Ingested 1916000 rows...
# Ingested 1917000 rows...
# Ingested 1918000 rows...
# Ingested 1919000 rows...
# Ingested 1920000 rows...
# Ingested 1921000 rows...
# Ingested 1922000 rows...
# Ingested 1923000 rows...
# Ingested 1924000 rows...
# Ingested 1925000 rows...
# Ingested 1926000 rows...
# Ingested 1927000 rows...
# Ingested 1928000 rows...
# Ingested 1929000 rows...
# Ingested 1930000 rows...
# Ingested 1931000 rows...
# Ingested 1932000 rows...
# Ingested 1933000 rows...
# Ingested 1934000 rows...
# Ingested 1935000 rows...
# Ingested 1936000 rows...
# Ingested 1937000 rows...
# Ingested 1938000 rows...
# Ingested 1939000 rows...
# Ingested 1940000 rows...
# Ingested 1941000 rows...
# Ingested 1942000 rows...
# Ingested 1943000 rows...
# Ingested 1944000 rows...
# Ingested 1945000 rows...
# Ingested 1946000 rows...
# Ingested 1947000 rows...
# Ingested 1948000 rows...
# Ingested 1949000 rows...
# Ingested 1950000 rows...
# Ingested 1951000 rows...
# Ingested 1952000 rows...
# Ingested 1953000 rows...
# Ingested 1954000 rows...
# Ingested 1955000 rows...
# Ingested 1956000 rows...
# Ingested 1957000 rows...
# Ingested 1958000 rows...
# Ingested 1959000 rows...
# Ingested 1960000 rows...
# Ingested 1961000 rows...
# Ingested 1962000 rows...
# Ingested 1963000 rows...
# Ingested 1964000 rows...
# ...
# Ingested 17076000 rows...
# Ingested 17077000 rows...
# Ingested 17078000 rows...
# Ingested 17079000 rows...
# Ingested 17080000 rows...
# Ingested 17081000 rows...
# Ingested 17082000 rows...
# Ingested 17083000 rows...
# Ingested 17084000 rows...
# Ingested 17085000 rows...
# Ingested 17086000 rows...
# Ingested 17087000 rows...
# Ingested 17088000 rows...
# Ingested 17089000 rows...
# Ingested 17090000 rows...
# Ingested 17091000 rows...
# Ingested 17092000 rows...
# Ingested 17093000 rows...
# Ingested 17094000 rows...
# Ingested 17095000 rows...
# Ingested 17096000 rows...
# Ingested 17097000 rows...
# Ingested 17098000 rows...
# Ingested 17099000 rows...
# Ingested 17100000 rows...
# Ingested 17101000 rows...
# Ingested 17102000 rows...
# Ingested 17103000 rows...
# Ingested 17104000 rows...
# Ingested 17105000 rows...
# Ingested 17106000 rows...
# Ingested 17107000 rows...
# Ingested 17108000 rows...
# Ingested 17109000 rows...
# Ingested 17110000 rows...
# Ingested 17111000 rows...
# Ingested 17112000 rows...
# Ingested 17113000 rows...
# Ingested 17114000 rows...
# Ingested 17115000 rows...
# Ingested 17116000 rows...
# Ingested 17117000 rows...
# Ingested 17118000 rows...
# Ingested 17119000 rows...
# Ingested 17120000 rows...
# Ingested 17121000 rows...
# Ingested 17122000 rows...
# Ingested 17123000 rows...
# Ingested 17124000 rows...
# Ingested 17125000 rows...
# Ingested 17126000 rows...
# Ingested 17127000 rows...
# Ingested 17128000 rows...
# Ingested 17129000 rows...
# Ingested 17130000 rows...
# Ingested 17131000 rows...
# Ingested 17132000 rows...
# Ingested 17133000 rows...
# Ingested 17134000 rows...
# Ingested 17135000 rows...
# Ingested 17136000 rows...
# Ingested 17137000 rows...
# Ingested 17138000 rows...
# Ingested 17139000 rows...
# Ingested 17140000 rows...
# Ingested 17141000 rows...
# Ingested 17142000 rows...
# Ingested 17143000 rows...
# Ingested 17144000 rows...
# Ingested 17145000 rows...
# Ingested 17146000 rows...
# Ingested 17147000 rows...
# Ingested 17148000 rows...
# Ingested 17149000 rows...
# Ingested 17150000 rows...
# Ingested 17151000 rows...
# Ingested 17152000 rows...
# Ingested 17153000 rows...
# Ingested 17154000 rows...
# Ingested 17155000 rows...
# Ingested 17156000 rows...
# Ingested 17157000 rows...
# Ingested 17158000 rows...
# Ingested 17159000 rows...
# Ingested 17160000 rows...
# Ingested 17161000 rows...
# Ingested 17162000 rows...
# Ingested 17163000 rows...
# Ingested 17164000 rows...
# Ingested 17165000 rows...
# Ingested 17166000 rows...
# Ingested 17167000 rows...
# Ingested 17168000 rows...
# Ingested 17169000 rows...
# Ingested 17170000 rows...
# Ingested 17171000 rows...
# Ingested 17172000 rows...
# Ingested 17173000 rows...
# Ingested 17174000 rows...
# Ingested 17175000 rows...
# Ingested 17176000 rows...
# Ingested 17177000 rows...
# Ingested 17178000 rows...
# Ingested 17179000 rows...
# Ingested 17180000 rows...
# Ingested 17181000 rows...
# Ingested 17182000 rows...
# Ingested 17183000 rows...
# Ingested 17184000 rows...
# Ingested 17185000 rows...
# Ingested 17186000 rows...
# Ingested 17187000 rows...
# Ingested 17188000 rows...
# Ingested 17189000 rows...
# Ingested 17190000 rows...
# Ingested 17191000 rows...
# Ingested 17192000 rows...
# Ingested 17193000 rows...
# Ingested 17194000 rows...
# Ingested 17195000 rows...
# Ingested 17196000 rows...
# Ingested 17197000 rows...
# Ingested 17198000 rows...
# Ingested 17199000 rows...
# Ingested 17200000 rows...
# Ingested 17201000 rows...
# Ingested 17202000 rows...
# Ingested 17203000 rows...
# Ingested 17204000 rows...
# Ingested 17205000 rows...
# Ingested 17206000 rows...
# Ingested 17207000 rows...
# Ingested 17208000 rows...
# Ingested 17209000 rows...
# Ingested 17210000 rows...
# Ingested 17211000 rows...
# Ingested 17212000 rows...
# Ingested 17213000 rows...
# Ingested 17214000 rows...
# Ingested 17215000 rows...
# Ingested 17216000 rows...
# Ingested 17217000 rows...
# Ingested 17218000 rows...
# Ingested 17219000 rows...
# Ingested 17220000 rows...
# Ingested 17221000 rows...
# Ingested 17222000 rows...
# Ingested 17223000 rows...
# Ingested 17224000 rows...
# Ingested 17225000 rows...
# Ingested 17226000 rows...
# Ingested 17227000 rows...
# Ingested 17228000 rows...
# Ingested 17229000 rows...
# Ingested 17230000 rows...
# Ingested 17231000 rows...
# Ingested 17232000 rows...
# Ingested 17233000 rows...
# Ingested 17234000 rows...
# Ingested 17235000 rows...
# Ingested 17236000 rows...
# Ingested 17237000 rows...
# Ingested 17238000 rows...
# Ingested 17239000 rows...
# Ingested 17240000 rows...
# Ingested 17241000 rows...
# Ingested 17242000 rows...
# Ingested 17243000 rows...
# Ingested 17244000 rows...
# Ingested 17245000 rows...
# Ingested 17246000 rows...
# Ingested 17247000 rows...
# Ingested 17248000 rows...
# Ingested 17249000 rows...
# Ingested 17250000 rows...
# Ingested 17251000 rows...
# Ingested 17252000 rows...
# Ingested 17253000 rows...
# Ingested 17254000 rows...
# Ingested 17255000 rows...
# Ingested 17256000 rows...
# Ingested 17257000 rows...
# Ingested 17258000 rows...
# Ingested 17259000 rows...
# Ingested 17260000 rows...
# Ingested 17261000 rows...
# Ingested 17262000 rows...
# Ingested 17263000 rows...
# Ingested 17264000 rows...
# Ingested 17265000 rows...
# Ingested 17266000 rows...
# Ingested 17267000 rows...
# Ingested 17268000 rows...
# Ingested 17269000 rows...
# Ingested 17270000 rows...
# Ingested 17271000 rows...
# Ingested 17272000 rows...
# Ingested 17273000 rows...
# Ingested 17274000 rows...
# Ingested 17275000 rows...
# Ingested 17276000 rows...
# Ingested 17277000 rows...
# Ingested 17278000 rows...
# Ingested 17279000 rows...
# Ingested 17280000 rows...
# Ingested 17281000 rows...
# Ingested 17282000 rows...
# Ingested 17283000 rows...
# Ingested 17284000 rows...
# Ingested 17285000 rows...
# Ingested 17286000 rows...
# Ingested 17287000 rows...
# Ingested 17288000 rows...
# Ingested 17289000 rows...
# Ingested 17290000 rows...
# Ingested 17291000 rows...
# Ingested 17292000 rows...
# Ingested 17293000 rows...
# Ingested 17294000 rows...
# Ingested 17295000 rows...
# Ingested 17296000 rows...
# Ingested 17297000 rows...
# Ingested 17298000 rows...
# Ingested 17299000 rows...
# Ingested 17300000 rows...
# Ingested 17301000 rows...
# Ingested 17302000 rows...
# Ingested 17303000 rows...
# Ingested 17304000 rows...
# Ingested 17305000 rows...
# Ingested 17306000 rows...
# Ingested 17307000 rows...
# Ingested 17308000 rows...
# Ingested 17309000 rows...
# Ingested 17310000 rows...
# Ingested 17311000 rows...
# Ingested 17312000 rows...
# Ingested 17313000 rows...
# Ingested 17314000 rows...
# Ingested 17315000 rows...
# Ingested 17316000 rows...
# Ingested 17317000 rows...
# Ingested 17318000 rows...
# Ingested 17319000 rows...
# Ingested 17320000 rows...
# Ingested 17321000 rows...
# Ingested 17322000 rows...
# Ingested 17323000 rows...
# Ingested 17324000 rows...
# Ingested 17325000 rows...
# Ingested 17326000 rows...
# Ingested 17327000 rows...
# Ingested 17328000 rows...
# Ingested 17329000 rows...
# Ingested 17330000 rows...
# Ingested 17331000 rows...
# Ingested 17332000 rows...
# Ingested 17333000 rows...
# Ingested 17334000 rows...
# Ingested 17335000 rows...
# Ingested 17336000 rows...
# Ingested 17337000 rows...
# Ingested 17338000 rows...
# Ingested 17339000 rows...
# Ingested 17340000 rows...
# Ingested 17341000 rows...
# Ingested 17342000 rows...
# Ingested 17343000 rows...
# Ingested 17344000 rows...
# Ingested 17345000 rows...
# Ingested 17346000 rows...
# Ingested 17347000 rows...
# Ingested 17348000 rows...
# Ingested 17349000 rows...
# Ingested 17350000 rows...
# Ingested 17351000 rows...
# Ingested 17352000 rows...
# Ingested 17353000 rows...
# Ingested 17354000 rows...
# Ingested 17355000 rows...
# Ingested 17356000 rows...
# Ingested 17357000 rows...
# Ingested 17358000 rows...
# Ingested 17359000 rows...
# Ingested 17360000 rows...
# Ingested 17361000 rows...
# Ingested 17362000 rows...
# Ingested 17363000 rows...
# Ingested 17364000 rows...
# Ingested 17365000 rows...
# Ingested 17366000 rows...
# Ingested 17367000 rows...
# Ingested 17368000 rows...
# Ingested 17369000 rows...
# Ingested 17370000 rows...
# Ingested 17371000 rows...
# Ingested 17372000 rows...
# Ingested 17373000 rows...
# Ingested 17374000 rows...
# Ingested 17375000 rows...
# Ingested 17376000 rows...
# Ingested 17377000 rows...
# Ingested 17378000 rows...
# Ingested 17379000 rows...
# Ingested 17380000 rows...
# Ingested 17381000 rows...
# Ingested 17382000 rows...
# Ingested 17383000 rows...
# Ingested 17384000 rows...
# Ingested 17385000 rows...
# Ingested 17386000 rows...
# Ingested 17387000 rows...
# Ingested 17388000 rows...
# Ingested 17389000 rows...
# Ingested 17390000 rows...
# Ingested 17391000 rows...
# Ingested 17392000 rows...
# Ingested 17393000 rows...
# Ingested 17394000 rows...
# Ingested 17395000 rows...
# Ingested 17396000 rows...
# Ingested 17397000 rows...
# Ingested 17398000 rows...
# Ingested 17399000 rows...
# Ingested 17400000 rows...
# Ingested 17401000 rows...
# Ingested 17402000 rows...
# Ingested 17403000 rows...
# Ingested 17404000 rows...
# Ingested 17405000 rows...
# Ingested 17406000 rows...
# Ingested 17407000 rows...
# Ingested 17408000 rows...
# Ingested 17409000 rows...
# Ingested 17410000 rows...
# Ingested 17411000 rows...
# Ingested 17412000 rows...
# Ingested 17413000 rows...
# Ingested 17414000 rows...
# Ingested 17415000 rows...
# Ingested 17416000 rows...
# Ingested 17417000 rows...
# Ingested 17418000 rows...
# Ingested 17419000 rows...
# Ingested 17420000 rows...
# Ingested 17421000 rows...
# Ingested 17422000 rows...
# Ingested 17423000 rows...
# Ingested 17424000 rows...
# Ingested 17425000 rows...
# Ingested 17426000 rows...
# Ingested 17427000 rows...
# Ingested 17428000 rows...
# Ingested 17429000 rows...
# Ingested 17430000 rows...
# Ingested 17431000 rows...
# Ingested 17432000 rows...
# Ingested 17433000 rows...
# Ingested 17434000 rows...
# Ingested 17435000 rows...
# Ingested 17436000 rows...
# Ingested 17437000 rows...
# Ingested 17438000 rows...
# Ingested 17439000 rows...
# Ingested 17440000 rows...
# Ingested 17441000 rows...
# Ingested 17442000 rows...
# Ingested 17443000 rows...
# Ingested 17444000 rows...
# Ingested 17445000 rows...
# Ingested 17446000 rows...
# Ingested 17447000 rows...
# Ingested 17448000 rows...
# Ingested 17449000 rows...
# Ingested 17450000 rows...
# Ingested 17451000 rows...
# Ingested 17452000 rows...
# Ingested 17453000 rows...
# Ingested 17454000 rows...
# Ingested 17455000 rows...
# Ingested 17456000 rows...
# Ingested 17457000 rows...
# Ingested 17458000 rows...
# Ingested 17459000 rows...
# Ingested 17460000 rows...
# Ingested 17461000 rows...
# Ingested 17462000 rows...
# Ingested 17463000 rows...
# Ingested 17464000 rows...
# Ingested 17465000 rows...
# Ingested 17466000 rows...
# Ingested 17467000 rows...
# Ingested 17468000 rows...
# Ingested 17469000 rows...
# Ingested 17470000 rows...
# Ingested 17471000 rows...
# Ingested 17472000 rows...
# Ingested 17473000 rows...
# Ingested 17474000 rows...
# Ingested 17475000 rows...
# Ingested 17476000 rows...
# Ingested 17477000 rows...
# Ingested 17478000 rows...
# Ingested 17479000 rows...
# Ingested 17480000 rows...
# Ingested 17481000 rows...
# Ingested 17482000 rows...
# Ingested 17483000 rows...
# Ingested 17484000 rows...
# Ingested 17485000 rows...
# Ingested 17486000 rows...
# Ingested 17487000 rows...
# Ingested 17488000 rows...
# Ingested 17489000 rows...
# Ingested 17490000 rows...
# Ingested 17491000 rows...
# Ingested 17492000 rows...
# Ingested 17493000 rows...
# Ingested 17494000 rows...
# Ingested 17495000 rows...
# Ingested 17496000 rows...
# Ingested 17497000 rows...
# Ingested 17498000 rows...
# Ingested 17499000 rows...
# Ingested 17500000 rows...
# Ingested 17501000 rows...
# Ingested 17502000 rows...
# Ingested 17503000 rows...
# Ingested 17504000 rows...
# Ingested 17505000 rows...
# Ingested 17506000 rows...
# Ingested 17507000 rows...
# Ingested 17508000 rows...
# Ingested 17509000 rows...
# Ingested 17510000 rows...
# Ingested 17511000 rows...
# Ingested 17512000 rows...
# Ingested 17513000 rows...
# Ingested 17514000 rows...
# Ingested 17515000 rows...
# Ingested 17516000 rows...
# Ingested 17517000 rows...
# Ingested 17518000 rows...
# Ingested 17519000 rows...
# Ingested 17520000 rows...
# Ingested 17521000 rows...
# Ingested 17522000 rows...
# Ingested 17523000 rows...
# Ingested 17524000 rows...
# Ingested 17525000 rows...
# Ingested 17526000 rows...
# Ingested 17527000 rows...
# Ingested 17528000 rows...
# Ingested 17529000 rows...
# Ingested 17530000 rows...
# Ingested 17531000 rows...
# Ingested 17532000 rows...
# Ingested 17533000 rows...
# Ingested 17534000 rows...
# Ingested 17535000 rows...
# Ingested 17536000 rows...
# Ingested 17537000 rows...
# Ingested 17538000 rows...
# Ingested 17539000 rows...
# Ingested 17540000 rows...
# Ingested 17541000 rows...
# Ingested 17542000 rows...
# Ingested 17543000 rows...
# Ingested 17544000 rows...
# Ingested 17545000 rows...
# Ingested 17546000 rows...
# Ingested 17547000 rows...
# Ingested 17548000 rows...
# Ingested 17549000 rows...
# Ingested 17550000 rows...
# Ingested 17551000 rows...
# Ingested 17552000 rows...
# Ingested 17553000 rows...
# Ingested 17554000 rows...
# Ingested 17555000 rows...
# Ingested 17556000 rows...
# Ingested 17557000 rows...
# Ingested 17558000 rows...
# Ingested 17559000 rows...
# Ingested 17560000 rows...
# Ingested 17561000 rows...
# Ingested 17562000 rows...
# Ingested 17563000 rows...
# Ingested 17564000 rows...
# Ingested 17565000 rows...
# Ingested 17566000 rows...
# Ingested 17567000 rows...
# Ingested 17568000 rows...
# Ingested 17569000 rows...
# Ingested 17570000 rows...
# Ingested 17571000 rows...
# Ingested 17572000 rows...
# Ingested 17573000 rows...
# Ingested 17574000 rows...
# Ingested 17575000 rows...
# Ingested 17576000 rows...
# Ingested 17577000 rows...
# Ingested 17578000 rows...
# Ingested 17579000 rows...
# Ingested 17580000 rows...
# Ingested 17581000 rows...
# Ingested 17582000 rows...
# Ingested 17583000 rows...
# Ingested 17584000 rows...
# Ingested 17585000 rows...
# Ingested 17586000 rows...
# Ingested 17587000 rows...
# Ingested 17588000 rows...
# Ingested 17589000 rows...
# Ingested 17590000 rows...
# Ingested 17591000 rows...
# Ingested 17592000 rows...
# Ingested 17593000 rows...
# Ingested 17594000 rows...
# Ingested 17595000 rows...
# Ingested 17596000 rows...
# Ingested 17597000 rows...
# Ingested 17598000 rows...
# Ingested 17599000 rows...
# Ingested 17600000 rows...
# Ingested 17601000 rows...
# Ingested 17602000 rows...
# Ingested 17603000 rows...
# Ingested 17604000 rows...
# Ingested 17605000 rows...
# Ingested 17606000 rows...
# Ingested 17607000 rows...
# Ingested 17608000 rows...
# Ingested 17609000 rows...
# Ingested 17610000 rows...
# Ingested 17611000 rows...
# Ingested 17612000 rows...
# Ingested 17613000 rows...
# Ingested 17614000 rows...
# Ingested 17615000 rows...
# Ingested 17616000 rows...
# Ingested 17617000 rows...
# Ingested 17618000 rows...
# Ingested 17619000 rows...
# Ingested 17620000 rows...
# Ingested 17621000 rows...
# Ingested 17622000 rows...
# Ingested 17623000 rows...
# Ingested 17624000 rows...
# Ingested 17625000 rows...
# Ingested 17626000 rows...
# Ingested 17627000 rows...
# Ingested 17628000 rows...
# Ingested 17629000 rows...
# Ingested 17630000 rows...
# Ingested 17631000 rows...
# Ingested 17632000 rows...
# Ingested 17633000 rows...
# Ingested 17634000 rows...
# Ingested 17635000 rows...
# Ingested 17636000 rows...
# Ingested 17637000 rows...
# Ingested 17638000 rows...
# Ingested 17639000 rows...
# Ingested 17640000 rows...
# Ingested 17641000 rows...
# Ingested 17642000 rows...
# Ingested 17643000 rows...
# Ingested 17644000 rows...
# Ingested 17645000 rows...
# Ingested 17646000 rows...
# Ingested 17647000 rows...
# Ingested 17648000 rows...
# Ingested 17649000 rows...
# Ingested 17650000 rows...
# Ingested 17651000 rows...
# Ingested 17652000 rows...
# Ingested 17653000 rows...
# Ingested 17654000 rows...
# Ingested 17655000 rows...
# Ingested 17656000 rows...
# Ingested 17657000 rows...
# Ingested 17658000 rows...
# Ingested 17659000 rows...
# Ingested 17660000 rows...
# Ingested 17661000 rows...
# Ingested 17662000 rows...
# Ingested 17663000 rows...
# Ingested 17664000 rows...
# Ingested 17665000 rows...
# Ingested 17666000 rows...
# Ingested 17667000 rows...
# Ingested 17668000 rows...
# Ingested 17669000 rows...
# Ingested 17670000 rows...
# Ingested 17671000 rows...
# Ingested 17672000 rows...
# Ingested 17673000 rows...
# Ingested 17674000 rows...
# Ingested 17675000 rows...
# Ingested 17676000 rows...
# Ingested 17677000 rows...
# Ingested 17678000 rows...
# Ingested 17679000 rows...
# Ingested 17680000 rows...
# Ingested 17681000 rows...
# Ingested 17682000 rows...
# Ingested 17683000 rows...
# Ingested 17684000 rows...
# Ingested 17685000 rows...
# Ingested 17686000 rows...
# Ingested 17687000 rows...
# Finished ingesting. Total rows: 17687886
# Total time: 6240.51 seconds

# %% [markdown]
# ## **3** Analytics Queries using MapReduce
# <font color = red>[60 marks]</font> <br>

# %% [markdown]
# #### 3.1 Total Revenue by Store
# <font color = red>[10 marks]</font> <br>

# %%
# !python revenue_by_store.py Liquor_Sales_Cleaned.csv > store_revenue_output_v2.txt
with open('store_revenue_output_v2.txt') as f:
    for line in f.readlines()[:10]:
        print(line.strip())
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\ACER\AppData\Local\Temp\revenue_by_store.ACER.20250721.180849.020513
# Running step 1 of 1...
# job output is in C:\Users\ACER\AppData\Local\Temp\revenue_by_store.ACER.20250721.180849.020513\output
# Streaming final output from C:\Users\ACER\AppData\Local\Temp\revenue_by_store.ACER.20250721.180849.020513\output...
# Removing temp directory C:\Users\ACER\AppData\Local\Temp\revenue_by_store.ACER.20250721.180849.020513...
# "ACKLEY"	225726.72
# "ADAIR"	189448.44
# "ADEL"	1349899.18
# "AFTON"	137832.15
# "AKRON"	134999.66
# "ALBIA"	1230812.32
# "ALDEN"	417606.28
# "ALGONA"	4135322.69
# "ALLISON"	225254.8
# "ALTA VISTA"	28472.98
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\ACER\AppData\Local\Temp\revenue_by_store.ACER.20250721.180916.671661
# Running step 1 of 1...
# job output is in C:\Users\ACER\AppData\Local\Temp\revenue_by_store.ACER.20250721.180916.671661\output
# Streaming final output from C:\Users\ACER\AppData\Local\Temp\revenue_by_store.ACER.20250721.180916.671661\output...
# Removing temp directory C:\Users\ACER\AppData\Local\Temp\revenue_by_store.ACER.20250721.180916.671661...

# %% [markdown]
# #### 3.2 Top-Selling Categories
# <font color = red>[10 marks]</font> <br>

# %%
# !python selling_categories.py Liquor_Sales_Cleaned.csv > selling_categories_v2.txt
with open('selling_categories_v2.txt') as f:
    for line in f.readlines()[:10]:
        print(line.strip())
# Out:
# " 15YR 200ml & 18YR 200ml\""	491
# " Aged 2 years\""	6
# " Kentucky Fire & Honey 3-pack\""	443
# " Pecan & Pineapple 50mls\""	545
# " Peppermint Schnapps\""	11730
# " Pet\""	31787
# " Pure Malt\""	42
# " White & Berry Mini\""	12321
# " White & Berry\""	97398
# " White and Berry Mini\""	1021
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\ACER\AppData\Local\Temp\selling_categories.ACER.20250721.181349.793371
# Running step 1 of 1...
# job output is in C:\Users\ACER\AppData\Local\Temp\selling_categories.ACER.20250721.181349.793371\output
# Streaming final output from C:\Users\ACER\AppData\Local\Temp\selling_categories.ACER.20250721.181349.793371\output...
# Removing temp directory C:\Users\ACER\AppData\Local\Temp\selling_categories.ACER.20250721.181349.793371...

# %% [markdown]
# #### 3.3 County-Level Sales Analysis
# <font color = red>[10 marks]</font> <br>

# %%
# !python country_level_sales_analysis.py Liquor_Sales_Cleaned.csv > country_level_sales_analysis_v2.txt
with open('country_level_sales_analysis_v2.txt') as f:
    for line in f.readlines()[:10]:
        print(line.strip())
# Out:
# " Ashby Co.\""	{"total_bottles":66,"total_sales":2817.42}
# " F.\""	{"total_bottles":2546,"total_sales":99806.89}
# " INC.\""	{"total_bottles":399038,"total_sales":8416707.71}
# " INC\""	{"total_bottles":18,"total_sales":584.82}
# " Inc.\""	{"total_bottles":16840720,"total_sales":217279944.16}
# " Inc\""	{"total_bottles":781465,"total_sales":14587157.17}
# " LLC.\""	{"total_bottles":84,"total_sales":2928.78}
# " LLC\""	{"total_bottles":122783,"total_sales":2233234.82}
# " Ltd.\""	{"total_bottles":20087,"total_sales":372545.05}
# " Ltd\""	{"total_bottles":12,"total_sales":231.0}
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\ACER\AppData\Local\Temp\country_level_sales_analysis.ACER.20250721.181552.796480
# Running step 1 of 1...
# job output is in C:\Users\ACER\AppData\Local\Temp\country_level_sales_analysis.ACER.20250721.181552.796480\output
# Streaming final output from C:\Users\ACER\AppData\Local\Temp\country_level_sales_analysis.ACER.20250721.181552.796480\output...
# Removing temp directory C:\Users\ACER\AppData\Local\Temp\country_level_sales_analysis.ACER.20250721.181552.796480...

# %% [markdown]
# #### 3.4 Store Performance Analysis
# <font color = red>[10 marks]</font> <br>

# %%
# !python store_performance_analysis.py Liquor_Sales_Cleaned.csv > store_performance_analysis_v2.txt
with open('store_performance_analysis_v2.txt') as f:
    for line in f.readlines()[:10]:
        print(line.strip())
# Out:
# "ACKLEY"	{"total_bottles":4903,"total_sales":59157.6,"transactions":518,"avg_sales_per_transaction":114.2}
# "ADAIR"	{"total_bottles":4185,"total_sales":44001.88,"transactions":375,"avg_sales_per_transaction":117.34}
# "ADEL"	{"total_bottles":24226,"total_sales":298165.76,"transactions":2235,"avg_sales_per_transaction":133.41}
# "AFTON"	{"total_bottles":3995,"total_sales":42506.98,"transactions":273,"avg_sales_per_transaction":155.7}
# "AKRON"	{"total_bottles":2955,"total_sales":31434.24,"transactions":340,"avg_sales_per_transaction":92.45}
# "ALBIA"	{"total_bottles":19267,"total_sales":246552.5,"transactions":1992,"avg_sales_per_transaction":123.77}
# "ALDEN"	{"total_bottles":8602,"total_sales":117627.56,"transactions":1105,"avg_sales_per_transaction":106.45}
# "ALGONA"	{"total_bottles":73704,"total_sales":894340.77,"transactions":5922,"avg_sales_per_transaction":151.02}
# "ALLISON"	{"total_bottles":4304,"total_sales":48521.79,"transactions":529,"avg_sales_per_transaction":91.72}
# "ALTA VISTA"	{"total_bottles":562,"total_sales":6992.28,"transactions":44,"avg_sales_per_transaction":158.92}
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\ACER\AppData\Local\Temp\store_performance_analysis.ACER.20250721.181757.056798
# Running step 1 of 1...
# job output is in C:\Users\ACER\AppData\Local\Temp\store_performance_analysis.ACER.20250721.181757.056798\output
# Streaming final output from C:\Users\ACER\AppData\Local\Temp\store_performance_analysis.ACER.20250721.181757.056798\output...
# Removing temp directory C:\Users\ACER\AppData\Local\Temp\store_performance_analysis.ACER.20250721.181757.056798...

# %% [markdown]
# #### 3.5 Trends in Liquor Sales Over Time
# <font color = red>[10 marks]</font> <br>

# %%
# !python trends_in_liquor_sales_over_time.py Liquor_Sales_Cleaned.csv > trends_in_liquor_sales_over_time_v2.txt
with open('trends_in_liquor_sales_over_time_v2.txt') as f:
    for line in f.readlines()[:10]:
        print(line.strip())
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\ACER\AppData\Local\Temp\trends_in_liquor_sales_over_time.ACER.20250721.183126.970717
# Running step 1 of 1...
# job output is in C:\Users\ACER\AppData\Local\Temp\trends_in_liquor_sales_over_time.ACER.20250721.183126.970717\output
# Streaming final output from C:\Users\ACER\AppData\Local\Temp\trends_in_liquor_sales_over_time.ACER.20250721.183126.970717\output...
# Removing temp directory C:\Users\ACER\AppData\Local\Temp\trends_in_liquor_sales_over_time.ACER.20250721.183126.970717...

# %% [markdown]
# #### 3.6 Vendor Performance
# <font color = red>[10 marks]</font> <br>

# %%
# !python vendor_performance.py Liquor_Sales_Cleaned.csv > vendor_performance_v2.txt
with open('vendor_performance_v2.txt') as f:
    for line in f.readlines()[:10]:
        print(line.strip())
# Out:
# "Anchor Distilling (PREISS IMPORTS)"	{"total_bottles":42,"total_sales":5544.84,"transactions":4,"avg_sales_per_transaction":1386.21}
# "DIAGEO AMERICAS"	{"total_bottles":111338,"total_sales":1418163.49,"transactions":8005,"avg_sales_per_transaction":177.16}
# "Diageo Americas"	{"total_bottles":7030,"total_sales":85843.85,"transactions":808,"avg_sales_per_transaction":106.24}
# "Hood River Distillers"	{"total_bottles":6,"total_sales":268.74,"transactions":1,"avg_sales_per_transaction":268.74}
# "Infinium Spirits"	{"total_bottles":24,"total_sales":982.8,"transactions":4,"avg_sales_per_transaction":245.7}
# "Jim Beam Brands"	{"total_bottles":443,"total_sales":5316.0,"transactions":31,"avg_sales_per_transaction":171.48}
# "McCormick Distilling Co."	{"total_bottles":11147,"total_sales":128669.61,"transactions":2051,"avg_sales_per_transaction":62.74}
# "Mccormick Distilling Company"	{"total_bottles":20640,"total_sales":235556.8,"transactions":3859,"avg_sales_per_transaction":61.04}
# "Pernod Ricard USA\/Austin Nichols"	{"total_bottles":491,"total_sales":25435.09,"transactions":86,"avg_sales_per_transaction":295.76}
# "Phillips Beverage"	{"total_bottles":545,"total_sales":6207.55,"transactions":125,"avg_sales_per_transaction":49.66}
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\ACER\AppData\Local\Temp\vendor_performance.ACER.20250721.182514.544760
# Running step 1 of 1...
# job output is in C:\Users\ACER\AppData\Local\Temp\vendor_performance.ACER.20250721.182514.544760\output
# Streaming final output from C:\Users\ACER\AppData\Local\Temp\vendor_performance.ACER.20250721.182514.544760\output...
# Removing temp directory C:\Users\ACER\AppData\Local\Temp\vendor_performance.ACER.20250721.182514.544760...
